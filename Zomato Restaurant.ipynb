# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_excel("C:\\Users\\vinay\\Downloads\\Country-Code.xlsx")
df1
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df2 = pd.read_csv("C:\\Users\\vinay\\Downloads\\zomato.csv", encoding='latin1')
df2
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
# first we need to merge both the table

# %%
df= pd.merge(df1, df2, on='Country Code', how='inner')

# %%
df
# Out:
#       Country Code        Country  Restaurant ID  \
# 0                1          India        3400025
# 1                1          India        3400341
# 2                1          India        3400005
# 3                1          India        3400021
# 4                1          India        3400017
# ...            ...            ...            ...
# 9546           216  United States       17697389
# 9547           216  United States       17697424
# 9548           216  United States       17697332
# 9549           216  United States       17694056
# 9550           216  United States       17559793
#
#                                Restaurant Name            City  \
# 0                                   Jahanpanah            Agra
# 1                          Rangrezz Restaurant            Agra
# 2                      Time2Eat - Mama Chicken            Agra
# 3        Chokho Jeeman Marwari Jain Bhojanalya            Agra
# ...

# %%
# after Merging the data we can see all the countries for the respective restaurant

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country Code          9551 non-null   int64
#  1   Country               9551 non-null   object
#  2   Restaurant ID         9551 non-null   int64
#  3   Restaurant Name       9551 non-null   object
#  4   City                  9551 non-null   object
#  5   Address               9551 non-null   object
#  6   Locality              9551 non-null   object
#  7   Locality Verbose      9551 non-null   object
#  8   Longitude             9551 non-null   float64
#  9   Latitude              9551 non-null   float64
#  10  Cuisines              9542 non-null   object
#  11  Average Cost for two  9551 non-null   int64
#  12  Currency              9551 non-null   object
#  13  Has Table booking     9551 non-null   object
#  14  Has Online delivery   9551 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Country Code            0
# Country                 0
# Restaurant ID           0
# Restaurant Name         0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
#The date have no null value which is a good

# %%
def un(df, a):
    unique_values = df[a].unique()
    return unique_values
coloumn=[]
coloumn=df.columns.tolist()
for i in coloumn:
    print(i)
    print(un(df,i))
    print("\n")
# Out:
# Country Code
# [  1  14  30  37  94 148 162 166 184 189 191 208 214 215 216]
#
#
# Country
# ['India' 'Australia' 'Brazil' 'Canada' 'Indonesia' 'New Zealand'
#  'Phillipines' 'Qatar' 'Singapore' 'South Africa' 'Sri Lanka' 'Turkey'
#  'UAE' 'United Kingdom' 'United States']
#
#
# Restaurant ID
# [ 3400025  3400341  3400005 ... 17697332 17694056 17559793]
#
#
# Restaurant Name
# ['Jahanpanah' 'Rangrezz Restaurant' 'Time2Eat - Mama Chicken' ...
#  'Tokyo Japanese Steak House' "Theo Yianni's Authentic Greek Restaurant"
#  "Fishpatrick's Crabby Cafe"]
#
#
# City
# ['Agra' 'Ahmedabad' 'Allahabad' 'Amritsar' 'Aurangabad' 'Bangalore'
#  'Bhopal' 'Bhubaneshwar' 'Chandigarh' 'Chennai' 'Coimbatore' 'Dehradun'
#  'Faridabad' 'Ghaziabad' 'Goa' 'Gurgaon' 'Guwahati' 'Hyderabad' 'Indore'
#  'Jaipur' 'Kanpur' 'Kochi' 'Kolkata' 'Lucknow' 'Ludhiana' 'Mangalore'
#  'Mohali' 'Mumbai' 'Mysore' 'Nagpur' 'Nashik' 'New Delhi' 'Noida'
#  'Panchkula' 'Patna' 'Puducherry' 'Pune' 'Ranchi' 'Secunderabad' 'Surat'
# ...

# %%
df=df.drop("Longitude",axis=1)
df=df.drop("Latitude",axis=1)
df=df.drop("Locality Verbose",axis=1)
df=df.drop("Address",axis=1)
df=df.drop("Restaurant ID",axis=1)
df=df.drop("Country",axis=1)
df=df.drop("Restaurant Name",axis=1)

# %%
# We need to drop above column because they have no use in the machine learning algorithm

# %%
def un(df, a):
    unique_values = df[a].unique()
    return unique_values
coloumn=[]
coloumn=df.columns.tolist()
for i in coloumn:
    print(i)
    print(un(df,i))
    print("\n")
# Out:
# Country Code
# [  1  14  30  37  94 148 162 166 184 189 191 208 214 215 216]
#
#
# City
# ['Agra' 'Ahmedabad' 'Allahabad' 'Amritsar' 'Aurangabad' 'Bangalore'
#  'Bhopal' 'Bhubaneshwar' 'Chandigarh' 'Chennai' 'Coimbatore' 'Dehradun'
#  'Faridabad' 'Ghaziabad' 'Goa' 'Gurgaon' 'Guwahati' 'Hyderabad' 'Indore'
#  'Jaipur' 'Kanpur' 'Kochi' 'Kolkata' 'Lucknow' 'Ludhiana' 'Mangalore'
#  'Mohali' 'Mumbai' 'Mysore' 'Nagpur' 'Nashik' 'New Delhi' 'Noida'
#  'Panchkula' 'Patna' 'Puducherry' 'Pune' 'Ranchi' 'Secunderabad' 'Surat'
#  'Vadodara' 'Varanasi' 'Vizag' 'Armidale' 'Balingup' 'Beechworth'
#  'Dicky Beach' 'East Ballina' 'Flaxton' 'Forrest' 'Hepburn Springs'
#  'Huskisson' 'Inverloch' 'Lakes Entrance' 'Lorn' 'Macedon' 'Mayfield'
#  'Middleton Beach' 'Montville' 'Palm Cove' 'Paynesville' 'Penola'
#  'Phillip Island' 'Tanunda' 'Trentham East' 'Victor Harbor' 'Brasí_lia'
#  'Rio de Janeiro' 'Sí£o Paulo' 'Chatham-Kent' 'Consort' 'Vineland Station'
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()
for col1 in df.columns:
    if df[col1].dtypes=="O":
        dfp=lab.fit_transform(df[col1])
        df[col1]=dfp

# %%
# with the help of above Code we are encoding the data which is in string value

# %%
df.describe()
# Out:
#        Country Code         City     Locality    Cuisines  \
# count   9551.000000  9551.000000  9551.000000  9551.00000
# mean      18.365616    78.301434   658.128468   989.95079
# std       56.750546    23.198915   315.866515   514.72354
# min        1.000000     0.000000     0.000000     0.00000
# 25%        1.000000    76.000000   381.000000   497.00000
# 50%        1.000000    88.000000   696.000000  1127.00000
# 75%        1.000000    88.000000   921.000000  1355.00000
# max      216.000000   140.000000  1207.000000  1825.00000
#
#        Average Cost for two     Currency  Has Table booking  \
# count           9551.000000  9551.000000        9551.000000
# mean            1199.210763     3.977699           0.121244
# std            16121.183073     0.914242           0.326428
# min                0.000000     0.000000           0.000000
# 25%              250.000000     4.000000           0.000000
# 50%              400.000000     4.000000           0.000000
# ...

# %%
df
# Out:
#       Country Code  City  Locality  Cuisines  Average Cost for two  Currency  \
# 0                1     1        17      1514                   850         4
# 1                1     1        17      1514                   700         4
# 2                1     1        17      1306                   500         4
# 3                1     1       204      1645                   400         4
# 4                1     1       204      1373                  1000         4
# ...            ...   ...       ...       ...                   ...       ...
# 9546           216   135      1174        18                    10         2
# 9547           216   135      1174      1795                    10         2
# 9548           216   135      1174      1125                    25         2
# 9549           216   136      1176       317                    25         2
# 9550           216   138      1186       327                    25         2
#
# ...

# %%
plt.figure(figsize=(24,24),facecolor="yellow")
plnum=1

for i in df.columns:
    if plnum<=20:
        ax=plt.subplot(5,4,plnum)
        sns.distplot(df[i])
        plt.xlabel(i,fontsize=20)
        
    plnum+=1
plt.show()

# %%
plt.figure(figsize=(24,24),facecolor="yellow")
plnum=1

for i in df:
    if plnum<=20:
        ax=plt.subplot(5,4,plnum)
        sns.boxplot(data=df[i])
        plt.xlabel(i,fontsize=20)
        
    plnum+=1
plt.show()

# %%
plt.figure(figsize=(24, 24), facecolor="yellow")
plnum = 1

for i in df:
    if plnum <= 20:
        ax = plt.subplot(4, 5, plnum)
        plt.scatter(df[i], df["Average Cost for two"]) 
        plt.xlabel(i, fontsize=20)
        plt.ylabel("Average Cost for two", fontsize=20)
    plnum += 1

plt.tight_layout()

# %%
# After looking at a Graph we can see The data is somewhat skewed but not too much

# %%
df
# Out:
#       Country Code  City  Locality  Cuisines  Average Cost for two  Currency  \
# 0                1     1        17      1514                   850         4
# 1                1     1        17      1514                   700         4
# 2                1     1        17      1306                   500         4
# 3                1     1       204      1645                   400         4
# 4                1     1       204      1373                  1000         4
# ...            ...   ...       ...       ...                   ...       ...
# 9546           216   135      1174        18                    10         2
# 9547           216   135      1174      1795                    10         2
# 9548           216   135      1174      1125                    25         2
# 9549           216   136      1176       317                    25         2
# 9550           216   138      1186       327                    25         2
#
# ...

# %%
def un(df, a):
    unique_values = df[a].unique()
    return unique_values
coloumn=[]
coloumn=df.columns.tolist()
for i in coloumn:
    print(i)
    print(un(df,i))
    print("\n")
# Out:
# Country Code
# [  1  14  30  37  94 148 162 166 184 189 191 208 214 215 216]
#
#
# City
# [  1   2   4   5  11  14  16  17  24  26  29  35  43  48  49  50  51  54
#   55  58  61  62  63  69  70  76  81  84  85  86  87  88  89  93  96 105
#  106 108 116 120 128 130 134   7  12  15  37  41  45  46  52  53  57  64
#   68  71  77  79  83  92  97  98 100 126 127 132  21 111 121  25  32 133
#  139  13  19  59 125   9 137  73  75  94  95 107 112 114 122 123  38 118
#   22  56  60 103 109 113  30   6 140   0  39 117  18  42  67  74   3   8
#   10  20  23  27  28  31  33  34  36  40  44  47  65  66  72  78  80  82
#   90  91  99 101 102 104 110 115 119 124 129 131 135 136 138]
#
#
# Locality
# [  17  204  226 ... 1174 1176 1186]
#
#
# Cuisines
# [1514 1306 1645 ...  615 1665  317]
#
#
# Average Cost for two
# [   850    700    500    400   1000   2000   2500    800   3600      0
#     550   1100   1500    900   1800    300   1400    350    450    600
# ...

# %%
df.skew()
# Out:
# Country Code             3.043965
# City                    -1.193777
# Locality                -0.253554
# Cuisines                -0.305484
# Average Cost for two    35.477915
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Switch to order menu     0.000000
# Price range              0.889618
# Aggregate rating        -0.954130
# Rating color             0.046009
# Rating text              0.431408
# Votes                    8.807637
# dtype: float64

# %%
def skwe(a,df):
    df[a]=np.sqrt(df[a])

# %%
skwe("Is delivering now",df)
skwe("Currency",df)

# %%
# with the helper above I'm in political science code we are removing the skewness from the data

# %%
skwe("Average Cost for two",df)

# %%
skwe("Votes",df)

# %%
df=df.drop("Is delivering now",axis=1)

# %%
df.skew()
# Out:
# Country Code            3.043965
# City                   -1.193777
# Locality               -0.253554
# Cuisines               -0.305484
# Average Cost for two    0.555148
# Currency               -0.819590
# Has Table booking       2.321100
# Has Online delivery     1.114620
# Switch to order menu    0.000000
# Price range             0.889618
# Aggregate rating       -0.954130
# Rating color            0.046009
# Rating text             0.431408
# Votes                   0.504859
# dtype: float64

# %%
cor=df.corr()
cor
# Out:
#                       Country Code      City  Locality  Cuisines  \
# Country Code              1.000000 -0.181728 -0.120075 -0.129451
# City                     -0.181728  1.000000  0.096444  0.025764
# Locality                 -0.120075  0.096444  1.000000  0.006499
# Cuisines                 -0.129451  0.025764  0.006499  1.000000
# Average Cost for two     -0.466840  0.033427  0.004249  0.078608
# Currency                 -0.192648 -0.052631  0.042579  0.085223
# Has Table booking        -0.061682 -0.003762 -0.065594  0.050232
# Has Online delivery      -0.154605  0.012723 -0.030993 -0.017180
# Switch to order menu           NaN       NaN       NaN       NaN
# Price range               0.243327 -0.105759 -0.114459 -0.005489
# Aggregate rating          0.282189 -0.132163 -0.174336 -0.079494
# Rating color             -0.187174  0.110887  0.036831 -0.016180
# Rating text               0.222685 -0.098985 -0.036969 -0.080025
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),linewidths=0.2,fmt=".2g",linecolor="black",annot=True,cmap="Blues_r")
plt.yticks(rotation=0);
plt.show()

# %%
cor['Average Cost for two'].sort_values(ascending=False)
# Out:
# Average Cost for two    1.000000
# Price range             0.490054
# Has Table booking       0.422098
# Currency                0.238085
# Votes                   0.211844
# Has Online delivery     0.197925
# Aggregate rating        0.142451
# Cuisines                0.078608
# City                    0.033427
# Locality                0.004249
# Rating color           -0.005379
# Rating text            -0.046339
# Country Code           -0.466840
# Switch to order menu         NaN
# Name: Average Cost for two, dtype: float64

# %%
x=df.drop('Average Cost for two',axis=1)

# %%
y=df["Average Cost for two"]

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#       Country Code      City  Locality  Cuisines  Currency  Has Table booking  \
# 0        -0.306015 -3.332289 -2.029851  1.018171  0.082507          -0.371446
# 1        -0.306015 -3.332289 -2.029851  1.018171  0.082507          -0.371446
# 2        -0.306015 -3.332289 -2.029851  0.614050  0.082507          -0.371446
# 3        -0.306015 -3.332289 -1.437798  1.272690  0.082507          -0.371446
# 4        -0.306015 -3.332289 -1.437798  0.744223  0.082507          -0.371446
# ...            ...       ...       ...       ...       ...                ...
# 9546      3.482693  2.444146  1.633280 -1.888396 -2.436538          -0.371446
# 9547      3.482693  2.444146  1.633280  1.564124 -2.436538          -0.371446
# 9548      3.482693  2.444146  1.633280  0.262386 -2.436538          -0.371446
# 9549      3.482693  2.487254  1.639612 -1.307471 -2.436538          -0.371446
# 9550      3.482693  2.573469  1.671273 -1.288042 -2.436538          -0.371446
#
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif values"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["feature"]=x.columns
vif
# Out:
#     vif values               feature
# 0     1.407741          Country Code
# 1     1.068318                  City
# 2     1.054119              Locality
# 3     1.038411              Cuisines
# 4     1.059784              Currency
# 5     1.426137     Has Table booking
# 6     1.158629   Has Online delivery
# 7          NaN  Switch to order menu
# 8     1.830827           Price range
# 9     3.603065      Aggregate rating
# 10    1.209575          Rating color
# 11    1.393290           Rating text
# 12    3.514119                 Votes

# %%
x=x.drop("Switch to order menu",axis=1)

# %%
#We have to drop the above column because it doesn't have any correlation with any field

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression




random_state_values = range(1, 300)

best_random_state = 0
best_accuracy = 0

for random_state in random_state_values:
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=random_state)
    
    
    model = LinearRegression()
    model.fit(x_train, y_train)
    
    
    y_pred = model.predict(x_test)
    
    
    accuracy = r2_score(y_test, y_pred)
    
    
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_random_state = random_state

print("Best random_state:", best_random_state)
print("Best accuracy:", best_accuracy)
# Out:
# Best random_state: 256
# Best accuracy: 0.7618371975202268

# %%
#We have the best accuracy at 256

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=256)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge
from sklearn.ensemble import GradientBoostingRegressor

# %%
lr=LinearRegression()
def modelB(z):
    z.fit(x_train,y_train)
    pred=z.predict(x_test)
    pred_t=z.predict(x_train)
    print("r2score result",(r2_score(y_test,pred)))
    print("r2score result on train data",r2_score(y_train,pred_t))
    print("Mean square error",mean_squared_error(y_test,pred))
    print("Mean absolute error",mean_absolute_error(y_test,pred))
    print("root mean square error",np.sqrt(mean_squared_error(y_test,pred)))

# %%
modelB(lr)
# Out:
# r2score result 0.7618371975202268
# r2score result on train data 0.6080652574773666
# Mean square error 0.017890849435859703
# Mean absolute error 0.07768704328875335
# root mean square error 0.13375667996724389

# %%
rf=RandomForestRegressor()
modelB(rf)
# Out:
# r2score result 0.8404107654266805
# r2score result on train data 0.9805694070807582
# Mean square error 0.011988383314299649
# Mean absolute error 0.059754702556159056
# root mean square error 0.1094914759892278

# %%
Dt=DecisionTreeRegressor()
modelB(Dt)
# Out:
# r2score result 0.7449575367936223
# r2score result on train data 0.9971739466811866
# Mean square error 0.01915885378181009
# Mean absolute error 0.07360019586132753
# root mean square error 0.13841551134829538

# %%
from sklearn.neighbors import KNeighborsRegressor 
KNN = KNeighborsRegressor(n_neighbors=5)

KNN.fit(x_train, y_train)

pred=KNN.predict(x_test)
pred_t=KNN.predict(x_train)
print("r2score result",(r2_score(y_test,pred)))
print("r2score result on train data",r2_score(y_train,pred_t))
print("Mean square error",mean_squared_error(y_test,pred))
print("Mean absolute error",mean_absolute_error(y_test,pred))
print("root mean square error",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2score result 0.7956331666943992
# r2score result on train data 0.8528902556818734
# Mean square error 0.01535208775797163
# Mean absolute error 0.07247763120443988
# root mean square error 0.12390354215264239

# %%
Gb=GradientBoostingRegressor()
modelB(Gb)
# Out:
# r2score result 0.8480989709568114
# r2score result on train data 0.8993313431314351
# Mean square error 0.011410843387244084
# Mean absolute error 0.06361719069572574
# root mean square error 0.10682154926438805

# %%
lo=Lasso()
modelB(lo)
# Out:
# r2score result -5.119418347554472e-05
# r2score result on train data 0.0
# Mean square error 0.0751240964457822
# Mean absolute error 0.1916354153797282
# root mean square error 0.2740877531846

# %%
ri=Ridge()
modelB(ri)
# Out:
# r2score result 0.7618339577026952
# r2score result on train data 0.6080652385409199
# Mean square error 0.017891092811764986
# Mean absolute error 0.07768396848161326
# root mean square error 0.13375758973518095

# %%
from sklearn.model_selection import cross_val_score
def crossval(a):
    s=cross_val_score(a,x,y)
    pr=a.predict(x_test)
    print(s)
    print(s.mean())
    print("difference in acc", (r2_score(y_test,pr)-s.mean()))

# %%
crossval(lr)
# Out:
# [ 0.57932722  0.81583377  0.74999731  0.81581874 -0.41689803]
# 0.5088158017406015
# difference in acc 0.25302139577962535

# %%
crossval(rf)
# Out:
# [ 0.18467321  0.85191344  0.81435211  0.85573444 -0.3611636 ]
# 0.4691019194234148
# difference in acc 0.3713088460032657

# %%
crossval(Dt)
# Out:
# [-0.65931813  0.75040266  0.6456264   0.77508843 -0.50354652]
# 0.2016505665914623
# difference in acc 0.54330697020216

# %%
crossval(KNN)
# Out:
# [-1.05695557  0.785926    0.74045393  0.77858178 -0.35707522]
# 0.17818618439200815
# difference in acc 0.617446982302391

# %%
crossval(Gb)
# Out:
# [ 0.625279    0.84809594  0.79730519  0.85573964 -0.33811323]
# 0.5576613084101462
# difference in acc 0.29043766254666525

# %%
crossval(lo)
# Out:
# [-0.22982966 -0.10170148 -0.00380808 -0.04133098 -0.21159678]
# -0.11765339573288643
# difference in acc 0.11760220154941088

# %%
crossval(ri)
# Out:
# [ 0.57946048  0.81583283  0.74999777  0.81580414 -0.41682886]
# 0.5088532723016017
# difference in acc 0.25298068540109353

# %%
#GradientBoostingRegressorIs the best machine learning model to use as it has a good R2score and crossval score

# %%
finalmodel= GradientBoostingRegressor()
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [50, 100],
    'max_depth': [None, 10],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'max_features': ['sqrt', 'log2'],
    'subsample': [0.8, 0.9], 
    'learning_rate': [0.01, 0.1], 
}


grid_search = GridSearchCV(estimator=finalmodel, param_grid=param_grid, cv=5,)
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.01, 0.1], 'max_depth': [None, 10],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5], 'n_estimators': [50, 100],
#                          'subsample': [0.8, 0.9]})

# %%
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'learning_rate': 0.1, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100, 'subsample': 0.9}

# %%
Lmodel = GradientBoostingRegressor(learning_rate= 0.1,max_depth=10, max_features='sqrt', min_samples_leaf=2,
                          min_samples_split=5, n_estimators=100, subsample=0.9)
Lmodel.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(max_depth=10, max_features='sqrt', min_samples_leaf=2,
#                           min_samples_split=5, subsample=0.9)

# %%
modelB(Lmodel)
# Out:
# r2score result 0.857968440753522
# r2score result on train data 0.9767278316106349
# Mean square error 0.01066944634158365
# Mean absolute error 0.06056515872500853
# root mean square error 0.10329301206559739

# %%
import pickle
filename="Average_Cost_for_two.pk1"
pickle.dump(Lmodel,open(filename,'wb'))

# %%
smodel=pickle.load(open("Average_Cost_for_two.pk1",'rb'))

# %%
re=smodel.predict(x_test)

# %%
con=pd.DataFrame([smodel.predict(x_test)[:],y_test[:]],index=["pred","og"])

# %%
con
# Out:
#           0         1         2         3         4         5         6     \
# pred  2.238173  2.341822  2.460436  2.830288  2.029425  2.047848  2.060933
# og    2.306143  2.200621  2.426038  2.899821  2.040047  2.079737  2.079737
#
#           7         8         9     ...      1901      1902      1903  \
# pred  2.221362  2.017903  2.243082  ...  2.129779  1.988958  2.214146
# og    2.200621  2.040047  2.200621  ...  2.114743  2.040047  2.174559
#
#           1904      1905      1906      1907      1908      1909      1910
# pred  1.981696  1.603930  2.119064  2.482299  1.984113  2.212648  2.181022
# og    1.939227  1.585833  2.114743  2.450433  2.040047  2.224687  2.174559
#
# [2 rows x 1911 columns]

# %%
# As you can see from the above table that are machine learning algorithm is somewhat Predicting the right value

# %%
df
# Out:
#       Country Code  City  Locality  Cuisines  Average Cost for two  Currency  \
# 0                1     1        17      1514              2.323686  2.000000
# 1                1     1        17      1514              2.267970  2.000000
# 2                1     1        17      1306              2.174559  2.000000
# 3                1     1       204      1645              2.114743  2.000000
# 4                1     1       204      1373              2.371374  2.000000
# ...            ...   ...       ...       ...                   ...       ...
# 9546           216   135      1174        18              1.333521  1.414214
# 9547           216   135      1174      1795              1.333521  1.414214
# 9548           216   135      1174      1125              1.495349  1.414214
# 9549           216   136      1176       317              1.495349  1.414214
# 9550           216   138      1186       327              1.495349  1.414214
#
# ...

# %%
x=df.drop("Price range",axis=1)

# %%
y=df["Price range"]

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#       Country Code      City  Locality  Cuisines  Average Cost for two  \
# 0        -0.306015 -3.332289 -2.029851  1.018171              0.678299
# 1        -0.306015 -3.332289 -2.029851  1.018171              0.491816
# 2        -0.306015 -3.332289 -2.029851  0.614050              0.179169
# 3        -0.306015 -3.332289 -1.437798  1.272690             -0.021039
# 4        -0.306015 -3.332289 -1.437798  0.744223              0.837912
# ...            ...       ...       ...       ...                   ...
# 9546      3.482693  2.444146  1.633280 -1.888396             -2.635804
# 9547      3.482693  2.444146  1.633280  1.564124             -2.635804
# 9548      3.482693  2.444146  1.633280  0.262386             -2.094164
# 9549      3.482693  2.487254  1.639612 -1.307471             -2.094164
# 9550      3.482693  2.573469  1.671273 -1.288042             -2.094164
#
#       Currency  Has Table booking  Has Online delivery  Switch to order menu  \
# ...

# %%
vif=pd.DataFrame()
vif["vif values"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["feature"]=x.columns
vif
# Out:
#     vif values               feature
# 0     1.887226          Country Code
# 1     1.068127                  City
# 2     1.054592              Locality
# 3     1.037448              Cuisines
# 4     1.886480  Average Cost for two
# 5     1.100245              Currency
# 6     1.300526     Has Table booking
# 7     1.156801   Has Online delivery
# 8          NaN  Switch to order menu
# 9     3.548701      Aggregate rating
# 10    1.211155          Rating color
# 11    1.367256           Rating text
# 12    3.539239                 Votes

# %%
x=x.drop("Switch to order menu",axis=1)

# %%
# We need to drop this field because it is have no correlation with any of the columns bash function

# %%
vif=pd.DataFrame()
vif["vif values"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["feature"]=x.columns
vif
# Out:
#     vif values               feature
# 0     1.887226          Country Code
# 1     1.068127                  City
# 2     1.054592              Locality
# 3     1.037448              Cuisines
# 4     1.886480  Average Cost for two
# 5     1.100245              Currency
# 6     1.300526     Has Table booking
# 7     1.156801   Has Online delivery
# 8     3.548701      Aggregate rating
# 9     1.211155          Rating color
# 10    1.367256           Rating text
# 11    3.539239                 Votes

# %%
y.value_counts()
# Out:
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price range, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score


random_state_values = range(1, 300)

best_random_state = 0
best_accuracy = 0

for random_state in random_state_values:
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=random_state)
    
    
    model = RandomForestClassifier()
    model.fit(x_train, y_train)
    
    
    y_pred = model.predict(x_test)
    
    
    accuracy = accuracy_score(y_test, y_pred)
    
    
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_random_state = random_state

print("Best random_state:", best_random_state)
print("Best accuracy:", best_accuracy)
# Out:
# Best random_state: 267
# Best accuracy: 0.9801151229722659

# %%
# we have the best accuracy at 267

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=267)

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,accuracy_score
from sklearn.model_selection import cross_val_score

# %%
def model(x):
    x.fit(x_train,y_train)
    pred=x.predict(x_test)
    print(accuracy_score(y_test,pred))
    print(confusion_matrix(y_test,pred))
    print(classification_report(y_test,pred))

# %%
ref=RandomForestClassifier()
model(ref)
# Out:
# 0.9738356881214024
# [[889   0   0   0]
#  [  6 634  13   0]
#  [  0  11 238   5]
#  [  1   0  14 100]]
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00       889
#            2       0.98      0.97      0.98       653
#            3       0.90      0.94      0.92       254
#            4       0.95      0.87      0.91       115
#
#     accuracy                           0.97      1911
#    macro avg       0.96      0.94      0.95      1911
# weighted avg       0.97      0.97      0.97      1911

# %%
ln=LogisticRegression()
model(ln)
# Out:
# 0.8791208791208791
# [[856  33   0   0]
#  [ 19 620  13   1]
#  [  5  53 185  11]
#  [ 12   4  80  19]]
#               precision    recall  f1-score   support
#
#            1       0.96      0.96      0.96       889
#            2       0.87      0.95      0.91       653
#            3       0.67      0.73      0.70       254
#            4       0.61      0.17      0.26       115
#
#     accuracy                           0.88      1911
#    macro avg       0.78      0.70      0.71      1911
# weighted avg       0.87      0.88      0.87      1911

# %%
ex=ExtraTreesClassifier()
model(ex)
# Out:
# 0.9445316588173731
# [[878  11   0   0]
#  [  5 623  24   1]
#  [  1  30 218   5]
#  [  1   1  27  86]]
#               precision    recall  f1-score   support
#
#            1       0.99      0.99      0.99       889
#            2       0.94      0.95      0.95       653
#            3       0.81      0.86      0.83       254
#            4       0.93      0.75      0.83       115
#
#     accuracy                           0.94      1911
#    macro avg       0.92      0.89      0.90      1911
# weighted avg       0.95      0.94      0.94      1911

# %%
svc=SVC()
model(svc)
# Out:
# 0.9105180533751962
# [[860  28   1   0]
#  [  7 606  40   0]
#  [  1  49 201   3]
#  [  1   3  38  73]]
#               precision    recall  f1-score   support
#
#            1       0.99      0.97      0.98       889
#            2       0.88      0.93      0.91       653
#            3       0.72      0.79      0.75       254
#            4       0.96      0.63      0.76       115
#
#     accuracy                           0.91      1911
#    macro avg       0.89      0.83      0.85      1911
# weighted avg       0.92      0.91      0.91      1911

# %%
gb=GradientBoostingClassifier()
model(gb)
# Out:
# 0.9764521193092621
# [[887   2   0   0]
#  [  5 638  10   0]
#  [  0  10 236   8]
#  [  0   0  10 105]]
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00       889
#            2       0.98      0.98      0.98       653
#            3       0.92      0.93      0.93       254
#            4       0.93      0.91      0.92       115
#
#     accuracy                           0.98      1911
#    macro avg       0.96      0.95      0.96      1911
# weighted avg       0.98      0.98      0.98      1911

# %%
ad=AdaBoostClassifier()
model(ad)
# Out:
# 0.8576661433804291
# [[883   6   0   0]
#  [ 13 628  11   1]
#  [  0 209  32  13]
#  [  0   8  11  96]]
#               precision    recall  f1-score   support
#
#            1       0.99      0.99      0.99       889
#            2       0.74      0.96      0.84       653
#            3       0.59      0.13      0.21       254
#            4       0.87      0.83      0.85       115
#
#     accuracy                           0.86      1911
#    macro avg       0.80      0.73      0.72      1911
# weighted avg       0.84      0.86      0.82      1911

# %%
bg=BaggingClassifier()
model(bg)
# Out:
# 0.9869178440607012
# [[888   1   0   0]
#  [  8 641   4   0]
#  [  0   6 246   2]
#  [  0   0   4 111]]
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      0.99       889
#            2       0.99      0.98      0.99       653
#            3       0.97      0.97      0.97       254
#            4       0.98      0.97      0.97       115
#
#     accuracy                           0.99      1911
#    macro avg       0.98      0.98      0.98      1911
# weighted avg       0.99      0.99      0.99      1911

# %%
def crossval(a):
    s=cross_val_score(a,x,y)
    pr=a.predict(x_test)
    print(s)
    print(s.mean())
    print("difference in acc", accuracy_score(y_test,pr)-s.mean())

# %%
crossval(ln)
# Out:
# [0.86342229 0.87172775 0.89005236 0.87801047 0.63664921]
# 0.8279724165139273
# difference in acc 0.05114846260695183

# %%
crossval(ref)
# Out:
# [0.90162219 0.96910995 0.99947644 0.93403141 0.62408377]
# 0.8856647516034203
# difference in acc 0.08817093651798213

# %%
crossval(ex)
# Out:
# [0.65567766 0.86753927 0.95759162 0.89371728 0.57696335]
# 0.7902978348004527
# difference in acc 0.15423382401692043

# %%
crossval(svc)
# Out:
# [0.79958137 0.88324607 0.94712042 0.8973822  0.61256545]
# 0.8279791014271194
# difference in acc 0.08253895194807681

# %%
crossval(gb)
# Out:
# [0.61329147 0.97277487 1.         0.93298429 0.62460733]
# 0.8287315925161849
# difference in acc 0.14772052679307723

# %%
crossval(ad)
# Out:
# [0.77708006 0.83717277 0.79947644 0.91832461 0.60418848]
# 0.787248473291854
# difference in acc 0.07041767008857513

# %%
crossval(bg)
# Out:
# [0.59916274 0.96701571 1.         0.94764398 0.69319372]
# 0.8414032290322492
# difference in acc 0.14708447374116784

# %%
# We are going to use RandomForestClassifier have the best confusing matrices Cross Val score

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [50, 100],
    'max_depth': [None, 10],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'max_features': ['sqrt', 'log2'],
    'class_weight': [None, 'balanced']
}

# %%
GCV= GridSearchCV(RandomForestClassifier(), param_grid, cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'class_weight': [None, 'balanced'],
#                          'max_depth': [None, 10],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [50, 100]})

# %%
best_params = GCV.best_params_

print("Best Hyperparameters:")
print(best_params)
# Out:
# Best Hyperparameters:
# {'class_weight': None, 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}

# %%
final_model=RandomForestClassifier(class_weight= None, max_depth= None, max_features= 'log2', min_samples_leaf= 1, min_samples_split= 2, n_estimators= 100)
final_model.fit(x_train,y_train)
pred=final_model.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 97.12192569335426

# %%
import joblib
joblib.dump(final_model,"Prange.pk1")
# Out:
# ['Prange.pk1']

# %%
model=joblib.load("Prange.pk1")

# %%
s=model.predict(x_test)

# %%
a=np.array(y_test)
z=pd.DataFrame({"pred":s,"real":a})
z
# Out:
#       pred  real
# 0        1     1
# 1        2     2
# 2        1     1
# 3        4     4
# 4        1     1
# ...    ...   ...
# 1906     1     1
# 1907     1     1
# 1908     1     1
# 1909     1     1
# 1910     3     3
#
# [1911 rows x 2 columns]
