# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("C:\\Users\\vinay\\Downloads\\baseball.csv")

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
# the data looks good as it not have any null value

# %%
def un(df, a):
    unique_values = df[a].unique()
    return unique_values
coloumn=[]
coloumn=df.columns.tolist()
for i in coloumn:
    print(i)
    print(un(df,i))
    print("\n")
# Out:
# W
# [ 95  83  81  76  74  93  87  80  78  88  86  85  68 100  98  97  64  90
#   71  67  63  92  84  79]
#
#
# R
# [724 696 669 622 689 891 764 713 644 748 751 729 661 656 694 647 697 655
#  640 683 703 613 573 626 667 720 650 737]
#
#
# AB
# [5575 5467 5439 5533 5605 5509 5567 5485 5640 5511 5459 5417 5544 5600
#  5484 5631 5491 5480 5571 5527 5428 5463 5420 5529 5385 5565 5649 5457
#  5572]
#
#
# H
# [1497 1349 1395 1381 1515 1480 1397 1370 1383 1495 1419 1363 1331 1379
#  1405 1386 1462 1341 1378 1382 1351 1420 1361 1374 1346 1486 1494 1324
#  1479]
#
#
# 2B
# [300 277 303 260 289 308 272 246 278 294 279 243 262 288 292 274 257 295
#  265 236 251 263]
#
#
# 3B
# [42 44 29 27 49 17 19 20 32 33 26 21 22 46 39 30 34 13 40 18 37 48 36]
#
#
# HR
# [139 156 141 136 151 232 212 217 167 161 172 230 176 198 146 137 140 171
#  145 177 120 100 130 187 154 148 186]
#
#
# BB
# [383 439 533 404 455 570 554 418 436 478 503 486 435 475 506 461 567 412
# ...

# %%
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64
#
#
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: R, dtype: int64
#
#
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# ...

# %%
df.nunique().to_frame("no.of unique values")
# Out:
#      no.of unique values
# W                     24
# R                     28
# AB                    29
# H                     29
# 2B                    22
# 3B                    23
# HR                    27
# BB                    29
# SO                    29
# SB                    27
# RA                    30
# ER                    30
# ERA                   30
# CG                     9
# SHO                   12
# SV                    20
# E                     21

# %%
plt.figure(figsize=(24,24),facecolor="yellow")
plnum=1

for i in df.columns:
    if plnum<=16:
        ax=plt.subplot(4,4,plnum)
        sns.distplot(df[i])
        plt.xlabel(i,fontsize=20)
        
    plnum+=1
plt.show()

# %%
# by seeing the above Graph data look good perfectly skewed

# %%
plt.figure(figsize=(24,24),facecolor="yellow")
plnum=1

for i in df:
    if plnum<=16:
        ax=plt.subplot(4,4,plnum)
        sns.boxplot(data=df[i])
        plt.xlabel(i,fontsize=20)
        
    plnum+=1
plt.show()

# %%
# even the data dont have any outliers

# %%
plt.figure(figsize=(24, 24), facecolor="yellow")
plnum = 1

for i in df:
    if plnum <= 16:
        ax = plt.subplot(4, 4, plnum)
        plt.scatter(df[i], df["W"]) 
        plt.xlabel(i, fontsize=20)
        plt.ylabel("W", fontsize=20)
    plnum += 1

plt.tight_layout()

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
def skwe(a,df):
    df[a]=np.sqrt(df[a])

# %%
skwe("R",df)

# %%
df.skew()
# Out:
# W      0.047089
# R      0.855443
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
cor=df.corr()
cor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.439998 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.439998  1.000000  0.333785  0.483305  0.565346 -0.051337  0.675441
# AB  -0.087947  0.333785  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.483305  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.565346  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.051337  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.675441 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.397653 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.036750 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081205  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.049137  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.047221  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),linewidths=0.2,fmt=".2g",linecolor="black",annot=True,cmap="Blues_r")
plt.yticks(rotation=0);
plt.show()

# %%
cor['W'].sort_values(ascending=False)
# Out:
# W      1.000000
# SV     0.666530
# BB     0.484342
# SHO    0.471805
# R      0.439998
# 2B     0.427797
# HR     0.307407
# SO     0.111850
# CG     0.080533
# H      0.037612
# AB    -0.087947
# E     -0.089485
# SB    -0.157234
# 3B    -0.251118
# ER    -0.809435
# RA    -0.812952
# ERA   -0.819600
# Name: W, dtype: float64

# %%
x=df.drop('W',axis=1)
y=df['W']

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.654663  0.847731  1.663685  1.420173  1.041193 -0.787299 -1.534902
# 1   0.168456 -0.711094 -0.970681  0.127403  1.235809 -0.243967 -0.536592
# 2  -0.314484 -1.115233 -0.151891  1.588795 -0.223808 -0.723377  1.139144
# 3  -1.191225  0.241522 -0.401088 -0.828122 -0.418423 -0.883181 -1.160536
# 4   0.044618  1.280738  1.984081  0.801892  1.722347 -0.403770 -0.251360
# 5   3.293724 -0.104884  1.361089  1.869832 -1.391501  2.185047  1.798742
# 6   1.325348  0.732263 -0.116292 -0.153633 -1.196885  1.545833  1.513510
# 7   0.465364 -0.451289 -0.596886 -1.615025 -1.099578  1.705636 -0.910958
# 8  -0.774866 -0.451289 -0.365489  0.183611  0.068115  0.107601 -0.590073
# 9   1.060309  1.785913  1.628086  1.082929  0.165423 -0.084163  0.158660
# 10  1.110326 -0.076017  0.275303  0.239818  0.068115  0.267405  0.604334
# 11  0.739995 -0.826562 -0.721484  0.183611 -0.515731  2.121125  0.301276
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif values"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["feature"]=x.columns
vif
# Out:
#      vif values feature
# 0     11.411369       R
# 1     13.127570      AB
# 2      9.570032       H
# 3      3.997470      2B
# 4      3.409283      3B
# 5     10.107933      HR
# 6      3.791282      BB
# 7      2.584931      SO
# 8      2.122036      SB
# 9    189.770398      RA
# 10  1688.578261      ER
# 11  1230.457534     ERA
# 12     3.011190      CG
# 13     3.661487     SHO
# 14     5.768314      SV
# 15     2.171151       E

# %%
# as we can see that data have many Fields which are Multi correlation so we have to drop them so our model can perform good

# %%
x=x.drop("R",axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif values"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["feature"]=x.columns
vif
# Out:
#     vif values feature
# 0     3.663993      AB
# 1     4.935353       H
# 2     3.016424      2B
# 3     2.754471      3B
# 4     1.919740      HR
# 5     2.792982      BB
# 6     2.016336      SO
# 7     1.721895      SB
# 8     4.701209      RA
# 9     2.242564      CG
# 10    3.146648     SHO
# 11    2.534207      SV
# 12    1.578206       E

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression




random_state_values = range(1, 200)

best_random_state = 0
best_accuracy = 0

for random_state in random_state_values:
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=random_state)
    
    
    model = LinearRegression()
    model.fit(x_train, y_train)
    
    
    y_pred = model.predict(x_test)
    
    
    accuracy = r2_score(y_test, y_pred)
    
    
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_random_state = random_state

print("Best random_state:", best_random_state)
print("Best accuracy:", best_accuracy)
# Out:
# Best random_state: 157
# Best accuracy: 0.9605162293430225

# %%
# the best accuracy is at 157 so we going to use that for creating the model

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=157)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge
from sklearn.ensemble import GradientBoostingRegressor

# %%
lr=LinearRegression()
def modelB(z):
    z.fit(x_train,y_train)
    pred=z.predict(x_test)
    pred_t=z.predict(x_train)
    print("r2score result",(r2_score(y_test,pred)))
    print("r2score result on train data",r2_score(y_train,pred_t))
    print("Mean square error",mean_squared_error(y_test,pred))
    print("Mean absolute error",mean_absolute_error(y_test,pred))
    print("root mean square error",np.sqrt(mean_squared_error(y_test,pred)))

# %%
modelB(lr)
# Out:
# r2score result 0.9605162293430225
# r2score result on train data 0.8596076394672771
# Mean square error 1.9050919341991648
# Mean absolute error 1.1096068323954047
# root mean square error 1.3802506780288735

# %%
rf=RandomForestRegressor()
modelB(rf)
# Out:
# r2score result 0.45926943005181375
# r2score result on train data 0.9145898781070746
# Mean square error 26.090249999999987
# Mean absolute error 3.974999999999999
# root mean square error 5.107861587787984

# %%
Dt=DecisionTreeRegressor()
modelB(Dt)
# Out:
# r2score result -1.0449050086355784
# r2score result on train data 1.0
# Mean square error 98.66666666666667
# Mean absolute error 8.0
# root mean square error 9.93310961716756

# %%
from sklearn.neighbors import KNeighborsRegressor 
KNN = KNeighborsRegressor(n_neighbors=5)

KNN.fit(x_train, y_train)

pred=KNN.predict(x_test)
pred_t=KNN.predict(x_train)
print("r2score result",(r2_score(y_test,pred)))
print("r2score result on train data",r2_score(y_train,pred_t))
print("Mean square error",mean_squared_error(y_test,pred))
print("Mean absolute error",mean_absolute_error(y_test,pred))
print("root mean square error",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2score result 0.7483937823834199
# r2score result on train data 0.5679827915869982
# Mean square error 12.139999999999988
# Mean absolute error 3.1666666666666643
# root mean square error 3.4842502780368676

# %%
Gb=GradientBoostingRegressor()
modelB(Gb)
# Out:
# r2score result -0.1292229922040109
# r2score result on train data 0.9999986952423227
# Mean square error 54.485009373843525
# Mean absolute error 5.33392648414209
# root mean square error 7.381396166975698

# %%
lo=Lasso()
modelB(lo)
# Out:
# r2score result 0.6825647218648687
# r2score result on train data 0.7972958221758073
# Mean square error 15.316252170020086
# Mean absolute error 3.5141832017262353
# root mean square error 3.9135983659568447

# %%
ri=Ridge()
modelB(ri)
# Out:
# r2score result 0.9304376775380403
# r2score result on train data 0.8570515822167224
# Mean square error 3.3563820587895563
# Mean absolute error 1.7299050659592747
# root mean square error 1.8320431378080475

# %%
from sklearn.model_selection import cross_val_score
def crossval(a):
    s=cross_val_score(a,x,y)
    pr=a.predict(x_test)
    print(s)
    print(s.mean())
    print("difference in acc", (r2_score(y_test,pr) - s.mean())*100)

# %%
crossval(lr)
# Out:
# [ 0.38309619 -3.28871787  0.22174455  0.16523547  0.76507894]
# -0.3507125442272079
# difference in acc 131.12287735702304

# %%
crossval(rf)
# Out:
# [ 0.24039334 -5.33320954  0.30968538  0.23845984  0.78256071]
# -0.7524220545316398
# difference in acc 121.16914845834535

# %%
crossval(Dt)
# Out:
# [ -3.42806394 -11.49236641  -0.88728104  -1.13814757   0.71065089]
# -3.247041614063258
# difference in acc 220.21366054276794

# %%
crossval(KNN)
# Out:
# [ 0.23758437 -3.92        0.01185072  0.22348509  0.44572781]
# -0.6002704020047221
# difference in acc 134.8664184388142

# %%
crossval(Gb)
# Out:
# [-0.31702641 -8.00693024 -0.14320722  0.07631389  0.7504702 ]
# -1.5280759555971042
# difference in acc 139.88529633930932

# %%
crossval(lo)
# Out:
# [ 0.41459689 -1.73650377  0.49898824  0.31094115  0.92781179]
# 0.08316686026240834
# difference in acc 59.93978616024604

# %%
crossval(ri)
# Out:
# [ 0.40721681 -2.58981474  0.40836403  0.42174984  0.8384801 ]
# -0.10280079148163698
# difference in acc 108.38839714234261

# %%
# by looking at all the score LinearRegression is the best model to use for the fianl model

# %%
from sklearn.model_selection import GridSearchCV
finalmodel=LinearRegression()
param_grid = {
    'fit_intercept': [True, False],
    'normalize': [True, False],
    'copy_X': [True, False],
}

# %%
grid_search = GridSearchCV(estimator=finalmodel, param_grid=param_grid, cv=5,)
grid_search.fit(x,y)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'normalize': [True, False]})

# %%
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'copy_X': True, 'fit_intercept': True, 'normalize': True}

# %%
lmodel=LinearRegression(copy_X=True,fit_intercept=True,normalize=True)
lmodel.fit(x,y)
# Out:
# LinearRegression(normalize=True)

# %%
modelB(lmodel)
# Out:
# r2score result 0.9605162293430222
# r2score result on train data 0.8596076394672769
# Mean square error 1.9050919341991828
# Mean absolute error 1.1096068323954071
# root mean square error 1.38025067802888

# %%
import pickle
filename="Baseball.pk1"
pickle.dump(lmodel,open(filename,'wb'))

# %%
smodel=pickle.load(open("Baseball.pk1",'rb'))

# %%
re=smodel.predict(x_test)

# %%
con=pd.DataFrame([smodel.predict(x_test)[:],y_test[:]],index=["pred","og"])

# %%
con
# Out:
#               0          1          2          3          4          5
# pred  70.251184  79.968865  86.089765  71.699101  68.359141  86.872114
# og    71.000000  81.000000  84.000000  74.000000  68.000000  87.000000
