# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset3/main/weatherAUS.csv")

# %%
df
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1     2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2     2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3     2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4     2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ...          ...      ...      ...      ...       ...          ...       ...
# 8420  2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 8421  2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 8422  2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 8423  2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 8424  2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   object
#  1   Location       8425 non-null   object
#  2   MinTemp        8350 non-null   float64
#  3   MaxTemp        8365 non-null   float64
#  4   Rainfall       8185 non-null   float64
#  5   Evaporation    4913 non-null   float64
#  6   Sunshine       4431 non-null   float64
#  7   WindGustDir    7434 non-null   object
#  8   WindGustSpeed  7434 non-null   float64
#  9   WindDir9am     7596 non-null   object
#  10  WindDir3pm     8117 non-null   object
#  11  WindSpeed9am   8349 non-null   float64
#  12  WindSpeed3pm   8318 non-null   float64
#  13  Humidity9am    8366 non-null   float64
#  14  Humidity3pm    8323 non-null   float64
#  15  Pressure9am    7116 non-null   float64
#  16  Pressure3pm    7113 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Date                0
# Location            0
# MinTemp            75
# MaxTemp            60
# Rainfall          240
# Evaporation      3512
# Sunshine         3994
# WindGustDir       991
# WindGustSpeed     991
# WindDir9am        829
# WindDir3pm        308
# WindSpeed9am       76
# WindSpeed3pm      107
# Humidity9am        59
# Humidity3pm       102
# Pressure9am      1309
# Pressure3pm      1312
# Cloud9am         2421
# Cloud3pm         2455
# Temp9am            56
# Temp3pm            96
# RainToday         240
# RainTomorrow      239
# dtype: int64

# %%
def un(df, a):
    unique_values = df[a].unique()
    return unique_values
coloumn=[]
coloumn=df.columns.tolist()
for i in coloumn:
    print(i)
    print(un(df,i))
    print("\n")
# Out:
# Date
# ['2008-12-01' '2008-12-02' '2008-12-03' ... '2013-06-06' '2013-06-07'
#  '2013-06-08']
#
#
# Location
# ['Albury' 'CoffsHarbour' 'Newcastle' 'Penrith' 'Williamtown' 'Wollongong'
#  'Melbourne' 'Brisbane' 'Adelaide' 'PerthAirport' 'Darwin' 'Uluru']
#
#
# MinTemp
# [13.4  7.4 12.9  9.2 17.5 14.6 14.3  7.7  9.7 13.1 15.9 12.6  8.4  9.8
#  14.1 13.5 11.2 11.5 17.1 20.5 15.3 16.2 16.9 20.1 19.7 12.5 12.  11.3
#   9.6 10.5 12.3 13.7 16.1 14.  17.  17.3 17.2 17.4 19.8 14.9 13.9 18.6
#  19.3 24.4 18.8 20.8 15.7 18.5 20.4 21.8 22.3 22.  28.  21.5 21.7 23.5
#  28.3 18.4 12.4 13.3 18.  18.7 15.5  8.9 15.  15.4 16.  12.8 13.2 13.8
#   7.6  8.3 11.  20.9 16.4 10.   8.8  9.3 14.4 10.8 10.1  9.1 10.4 12.2
#  10.7  7.8  8.1  7.5  8.2 11.6 13.   9.9  3.5  6.6  7.   5.7  6.2  6.
#  10.6  8.6  4.5  5.4  2.1  1.8  7.2  4.6  4.2  5.2  4.1  3.2  4.3  3.7
#   3.6  6.9 10.3  3.   2.6  5.1  4.4  4.7  6.7  8.   2.2  1.7  2.8  9.
#   6.3 -2.  -1.3  2.   0.5  1.2  0.6  0.9  5.   3.9  3.4  0.  -1.5 -1.7
# ...

# %%
df["MinTemp"] = df["MinTemp"].fillna(df["MinTemp"].mean())

# %%
df["MaxTemp"] = df["MaxTemp"].fillna(df["MaxTemp"].mean())

# %%
df["RainToday"] = df["RainToday"].fillna(df["RainToday"].mode().iloc[0])

# %%
df["RainTomorrow"] = df["RainTomorrow"].fillna(df["RainTomorrow"].mode().iloc[0])

# %%
df["RainTomorrow"] = df["RainTomorrow"].fillna(df["RainTomorrow"].mode().iloc[0])

# %%
df["WindDir9am"] = df["WindDir9am"].fillna(df["WindDir9am"].mode().iloc[0])

# %%
df["WindDir3pm"] = df["WindDir3pm"].fillna(df["WindDir3pm"].mode().iloc[0])

# %%
df["WindGustDir"] = df["WindGustDir"].fillna(df["WindGustDir"].mode().iloc[0])

# %%
# With the above code we are filling all the na with mean and mode

# %%
df.isnull().sum()
# Out:
# Date                0
# Location            0
# MinTemp             0
# MaxTemp             0
# Rainfall          240
# Evaporation      3512
# Sunshine         3994
# WindGustDir         0
# WindGustSpeed     991
# WindDir9am          0
# WindDir3pm          0
# WindSpeed9am       76
# WindSpeed3pm      107
# Humidity9am        59
# Humidity3pm       102
# Pressure9am      1309
# Pressure3pm      1312
# Cloud9am         2421
# Cloud3pm         2455
# Temp9am            56
# Temp3pm            96
# RainToday           0
# RainTomorrow        0
# dtype: int64

# %%
df.describe()
# Out:
#            MinTemp      MaxTemp     Rainfall  Evaporation     Sunshine  \
# count  8425.000000  8425.000000  8185.000000  4913.000000  4431.000000
# mean     13.193305    23.859976     2.805913     5.389395     7.632205
# std       5.379488     6.114516    10.459379     5.044484     3.896235
# min      -2.000000     8.200000     0.000000     0.000000     0.000000
# 25%       9.300000    19.300000     0.000000     2.600000     4.750000
# 50%      13.200000    23.300000     0.000000     4.600000     8.700000
# 75%      17.300000    28.000000     1.000000     7.000000    10.700000
# max      28.500000    45.500000   371.000000   145.000000    13.900000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count    7434.000000   8349.000000   8318.000000  8366.000000  8323.000000
# mean       40.174469     13.847646     18.533662    67.822496    51.249790
# std        14.665721     10.174579      9.766986    16.833283    18.423774
# ...

# %%
for col in df.columns:
    i=df[col].isnull().sum()
    if i >0:
        df[col] = df[col].fillna(df[col].mean())

# %%
# the above code is also helping to fill all the nan with the mean

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()
for col1 in df.columns:
    if df[col1].dtypes=="O":
        dfp=lab.fit_transform(df[col1])
        df[col1]=dfp

# %%
df
# Out:
#       Date  Location  MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0        0         1     13.4  22.900000       0.6     5.389395  7.632205
# 1        1         1      7.4  25.100000       0.0     5.389395  7.632205
# 2        2         1     12.9  25.700000       0.0     5.389395  7.632205
# 3        3         1      9.2  28.000000       0.0     5.389395  7.632205
# 4        4         1     17.5  32.300000       1.0     5.389395  7.632205
# ...    ...       ...      ...        ...       ...          ...       ...
# 8420  2999         9      2.8  23.400000       0.0     5.389395  7.632205
# 8421  3000         9      3.6  25.300000       0.0     5.389395  7.632205
# 8422  3001         9      5.4  26.900000       0.0     5.389395  7.632205
# 8423  3002         9      7.8  27.000000       0.0     5.389395  7.632205
# 8424  3003         9     14.9  23.859976       0.0     5.389395  7.632205
#
#       WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  Humidity3pm  \
# ...

# %%
df=df.drop("Date",axis=1)

# %%
df=df.drop("Location",axis=1)

# %%
# We are dropping the above field as it doesn't have any importance in our model buildings

# %%
def un(df, a):
    unique_values = df[a].unique()
    return unique_values
coloumn=[]
coloumn=df.columns.tolist()
for i in coloumn:
    print(i)
    print(un(df,i))
    print("\n")
# Out:
# MinTemp
# [13.4         7.4        12.9         9.2        17.5        14.6
#  14.3         7.7         9.7        13.1        15.9        12.6
#   8.4         9.8        14.1        13.5        11.2        11.5
#  17.1        20.5        15.3        16.2        16.9        20.1
#  19.7        12.5        12.         11.3         9.6        10.5
#  12.3        13.7        16.1        14.         17.         17.3
#  17.2        17.4        19.8        14.9        13.9        18.6
#  19.3        24.4        18.8        20.8        15.7        18.5
#  20.4        21.8        22.3        22.         28.         21.5
#  21.7        23.5        28.3        18.4        12.4        13.3
#  18.         18.7        15.5         8.9        15.         15.4
#  16.         12.8        13.2        13.8         7.6         8.3
#  11.         20.9        16.4        10.          8.8         9.3
#  14.4        10.8        10.1         9.1        10.4        12.2
# ...

# %%
plt.figure(figsize=(24,24),facecolor="yellow")
plnum=1

for i in df.columns:
    if plnum<=24:
        ax=plt.subplot(5,5,plnum)
        sns.distplot(df[i])
        plt.xlabel(i,fontsize=20)
        
    plnum+=1
plt.show()

# %%
plt.figure(figsize=(24,24),facecolor="yellow")
plnum=1

for i in df:
    if plnum<=23:
        ax=plt.subplot(5,5,plnum)
        sns.boxplot(data=df[i])
        plt.xlabel(i,fontsize=20)
        
    plnum+=1
plt.show()

# %%
plt.figure(figsize=(24, 24), facecolor="yellow")
plnum = 1

for i in df:
    if plnum <= 25:
        ax = plt.subplot(5, 5, plnum)
        plt.scatter(df[i], df["RainTomorrow"]) 
        plt.xlabel(i, fontsize=20)
        plt.ylabel("RainTomorrow", fontsize=20)
    plnum += 1

plt.tight_layout()

# %%
# By seeing all the graph we can say the data is somewhat good to go and doesn't need any additional cleanliness but might have skewness which we will deal with after seeing that

# %%
df.skew()
# Out:
# MinTemp          -0.089989
# MaxTemp           0.380654
# Rainfall         13.218403
# Evaporation      14.023948
# Sunshine         -0.716525
# WindGustDir       0.119640
# WindGustSpeed     0.757000
# WindDir9am        0.172792
# WindDir3pm       -0.119847
# WindSpeed9am      0.960591
# WindSpeed3pm      0.494217
# Humidity9am      -0.256743
# Humidity3pm       0.118281
# Pressure9am      -0.024082
# Pressure3pm      -0.010214
# Cloud9am         -0.366503
# Cloud3pm         -0.276294
# Temp9am          -0.014748
# Temp3pm           0.397331
# RainToday         1.242362
# RainTomorrow      1.241588
# dtype: float64

# %%
def skwe(a,df):
    df[a]=np.sqrt(df[a])

# %%
skwe("Rainfall",df)
skwe("Evaporation",df)

# %%
skwe("Rainfall",df)

# %%
# As you can see in the graph the data have skewness so we are trying to reduce it using the work code

# %%
df.skew()
# Out:
# MinTemp         -0.089989
# MaxTemp          0.380654
# Rainfall         0.712112
# Evaporation     -0.538867
# Sunshine        -0.716525
# WindGustDir      0.119640
# WindGustSpeed    0.757000
# WindDir9am       0.172792
# WindDir3pm      -0.119847
# WindSpeed9am     0.960591
# WindSpeed3pm     0.494217
# Humidity9am     -0.256743
# Humidity3pm      0.118281
# Pressure9am     -0.024082
# Pressure3pm     -0.010214
# Cloud9am        -0.366503
# Cloud3pm        -0.276294
# Temp9am         -0.014748
# Temp3pm          0.397331
# RainToday        1.242362
# RainTomorrow     1.241588
# dtype: float64

# %%
cor=df.corr()
cor
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.717522  0.071834     0.343629  0.056184
# MaxTemp        0.717522  1.000000 -0.250810     0.439824  0.378403
# Rainfall       0.071834 -0.250810  1.000000    -0.172890 -0.285342
# Evaporation    0.343629  0.439824 -0.172890     1.000000  0.348443
# Sunshine       0.056184  0.378403 -0.285342     0.348443  1.000000
# WindGustDir   -0.145316 -0.224670  0.140939    -0.105547 -0.105918
# WindGustSpeed  0.230058  0.139998  0.083342     0.155868 -0.013778
# WindDir9am    -0.041650 -0.214119  0.167292    -0.074993 -0.076560
# WindDir3pm    -0.147166 -0.180622  0.118183    -0.045961 -0.068553
# WindSpeed9am   0.136872  0.013314  0.023822     0.090887 -0.018069
# WindSpeed3pm   0.178349  0.088172  0.027451     0.089567  0.030145
# Humidity9am   -0.130731 -0.390976  0.432023    -0.278951 -0.360831
# Humidity3pm    0.079048 -0.421879  0.402910    -0.212488 -0.440268
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),linewidths=0.2,fmt=".2g",linecolor="black",annot=True,cmap="Blues_r")
plt.yticks(rotation=0);
plt.show()

# %%
cor['RainTomorrow'].sort_values(ascending=False)
# Out:
# RainTomorrow     1.000000
# Humidity3pm      0.444808
# Cloud3pm         0.344369
# Rainfall         0.330416
# RainToday        0.312929
# Cloud9am         0.278943
# Humidity9am      0.271222
# WindGustSpeed    0.190127
# MinTemp          0.092942
# WindSpeed9am     0.068285
# WindSpeed3pm     0.053568
# WindGustDir      0.051832
# WindDir9am       0.032860
# WindDir3pm       0.008918
# Temp9am         -0.023211
# Evaporation     -0.077306
# Pressure3pm     -0.135242
# MaxTemp         -0.152886
# Pressure9am     -0.163985
# Temp3pm         -0.193805
# Sunshine        -0.327731
# Name: RainTomorrow, dtype: float64

# %%
x=df.drop('RainTomorrow',axis=1)

# %%
y=df['RainTomorrow']

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#        MinTemp       MaxTemp  Rainfall  Evaporation      Sunshine  \
# 0     0.038425 -1.570089e-01  0.899784     0.204766  1.257472e-15
# 1    -1.076989  2.028121e-01 -0.745855     0.204766  1.257472e-15
# 2    -0.054526  3.009450e-01 -0.745855     0.204766  1.257472e-15
# 3    -0.742365  6.771214e-01 -0.745855     0.204766  1.257472e-15
# 4     0.800625  1.380408e+00  1.008291     0.204766  1.257472e-15
# ...        ...           ...       ...          ...           ...
# 8420 -1.932140 -7.523137e-02 -0.745855     0.204766  1.257472e-15
# 8421 -1.783418  2.355231e-01 -0.745855     0.204766  1.257472e-15
# 8422 -1.448794  4.972110e-01 -0.745855     0.204766  1.257472e-15
# 8423 -1.002628  5.135665e-01 -0.745855     0.204766  1.257472e-15
# 8424  0.317279 -2.905320e-15 -0.745855     0.204766  1.257472e-15
#
#       WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  \
# 0        1.229643       0.277710    1.249535    1.397222      0.607461
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif values"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["feature"]=x.columns
vif
# Out:
#     vif values        feature
# 0     8.072381        MinTemp
# 1    26.307483        MaxTemp
# 2     3.456815       Rainfall
# 3     1.415314    Evaporation
# 4     1.924122       Sunshine
# 5     1.582734    WindGustDir
# 6     2.384015  WindGustSpeed
# 7     1.336511     WindDir9am
# 8     1.477492     WindDir3pm
# 9     2.011100   WindSpeed9am
# 10    1.949333   WindSpeed3pm
# 11    3.943161    Humidity9am
# 12    5.457478    Humidity3pm
# 13   20.603328    Pressure9am
# 14   19.490947    Pressure3pm
# 15    1.934827       Cloud9am
# 16    1.820838       Cloud3pm
# 17   16.921116        Temp9am
# 18   32.853412        Temp3pm
# 19    3.125629      RainToday

# %%
x=x.drop("Pressure9am",axis=1)

# %%
x=x.drop("Temp9am",axis=1)

# %%
x=x.drop("Temp3pm",axis=1)

# %%
# Some columns had need to be dropped as it may lead to multi correlation and over fit the model

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif values"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["feature"]=x.columns
vif
# Out:
#     vif values        feature
# 0     4.281666        MinTemp
# 1     5.406950        MaxTemp
# 2     3.442743       Rainfall
# 3     1.401921    Evaporation
# 4     1.915525       Sunshine
# 5     1.564552    WindGustDir
# 6     2.318506  WindGustSpeed
# 7     1.317415     WindDir9am
# 8     1.396720     WindDir3pm
# 9     1.990689   WindSpeed9am
# 10    1.891941   WindSpeed3pm
# 11    2.433991    Humidity9am
# 12    2.890133    Humidity3pm
# 13    1.467111    Pressure3pm
# 14    1.918502       Cloud9am
# 15    1.808379       Cloud3pm
# 16    3.118844      RainToday

# %%
y.value_counts()
# Out:
# 0    6434
# 1    1991
# Name: RainTomorrow, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

# %%
sm=SMOTE()
x,y=sm.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 0    6434
# 1    6434
# Name: RainTomorrow, dtype: int64

# %%
# As data is in balance we need to balance the data so our model can have a proper set to learn on

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score


random_state_values = range(1, 300)

best_random_state = 0
best_accuracy = 0

for random_state in random_state_values:
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=random_state)
    
    
    model = RandomForestClassifier()
    model.fit(x_train, y_train)
    
    
    y_pred = model.predict(x_test)
    
    
    accuracy = accuracy_score(y_test, y_pred)
    
    
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_random_state = random_state

print("Best random_state:", best_random_state)
print("Best accuracy:", best_accuracy)
# Out:
# Best random_state: 18
# Best accuracy: 0.945998445998446

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=18)

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,accuracy_score
from sklearn.model_selection import cross_val_score

# %%
def model(x):
    x.fit(x_train,y_train)
    pred=x.predict(x_test)
    print(accuracy_score(y_test,pred))
    print(confusion_matrix(y_test,pred))
    print(classification_report(y_test,pred))

# %%
ref=RandomForestClassifier()
model(ref)
# Out:
# 0.9463869463869464
# [[1226   70]
#  [  68 1210]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95      1296
#            1       0.95      0.95      0.95      1278
#
#     accuracy                           0.95      2574
#    macro avg       0.95      0.95      0.95      2574
# weighted avg       0.95      0.95      0.95      2574

# %%
ln=LogisticRegression()
model(ln)
# Out:
# 0.7832167832167832
# [[1046  250]
#  [ 308  970]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.81      0.79      1296
#            1       0.80      0.76      0.78      1278
#
#     accuracy                           0.78      2574
#    macro avg       0.78      0.78      0.78      2574
# weighted avg       0.78      0.78      0.78      2574

# %%
ex=ExtraTreesClassifier()
model(ex)
# Out:
# 0.9514374514374514
# [[1220   76]
#  [  49 1229]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95      1296
#            1       0.94      0.96      0.95      1278
#
#     accuracy                           0.95      2574
#    macro avg       0.95      0.95      0.95      2574
# weighted avg       0.95      0.95      0.95      2574

# %%
svc=SVC()
model(svc)
# Out:
# 0.8445998445998446
# [[1089  207]
#  [ 193 1085]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.84      1296
#            1       0.84      0.85      0.84      1278
#
#     accuracy                           0.84      2574
#    macro avg       0.84      0.84      0.84      2574
# weighted avg       0.84      0.84      0.84      2574

# %%
ad=AdaBoostClassifier()
model(ad)
# Out:
# 0.811965811965812
# [[1074  222]
#  [ 262 1016]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.83      0.82      1296
#            1       0.82      0.79      0.81      1278
#
#     accuracy                           0.81      2574
#    macro avg       0.81      0.81      0.81      2574
# weighted avg       0.81      0.81      0.81      2574

# %%
bg=BaggingClassifier()
model(bg)
# Out:
# 0.925019425019425
# [[1216   80]
#  [ 113 1165]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93      1296
#            1       0.94      0.91      0.92      1278
#
#     accuracy                           0.93      2574
#    macro avg       0.93      0.92      0.92      2574
# weighted avg       0.93      0.93      0.93      2574

# %%
def crossval(a):
    s=cross_val_score(a,x,y)
    pr=a.predict(x_test)
    print(s)
    print(s.mean())
    print("difference in acc", accuracy_score(y_test,pr)-s.mean())

# %%
crossval(ln)
# Out:
# [0.77466977 0.71367521 0.68609169 0.75359503 0.83365721]
# 0.7523377818364215
# difference in acc 0.030879001380361704

# %%
crossval(ref)
# Out:
# [0.85586636 0.77428127 0.90520591 0.90827827 0.91061018]
# 0.8708483984815116
# difference in acc 0.0755385479054348

# %%
crossval(ex)
# Out:
# [0.88539239 0.83644134 0.92229992 0.9288768  0.92226972]
# 0.8990560331407591
# difference in acc 0.052381418296692295

# %%
crossval(svc)
# Out:
# [0.8030303  0.70668221 0.75330225 0.80917217 0.8177225 ]
# 0.7779818876981721
# difference in acc 0.06661795690167249

# %%
crossval(ad)
# Out:
# [0.74436674 0.67094017 0.72105672 0.77030703 0.82782744]
# 0.7468996219482034
# difference in acc 0.0650661900176086

# %%
crossval(bg)
# Out:
# [0.83682984 0.74009324 0.9032634  0.89040031 0.89467548]
# 0.8530524534411048
# difference in acc 0.07196697157832022

# %%
# We are using ExtraTreesClassifier As it is more accurate than other models and also have a good crossvall score

# %%
from sklearn.model_selection import GridSearchCV
param_grid =  {
    'n_estimators': [50, 100],
    'max_depth': [None, 10,],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'max_features': ['auto', 'sqrt', 'log2'],
}

# %%
GGV=GridSearchCV(ExtraTreesClassifier(),param_grid,cv=5)

# %%
GGV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesClassifier(),
#              param_grid={'max_depth': [None, 10],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [50, 100]})

# %%
best_params = GGV.best_params_

print("Best Hyperparameters:")
print(best_params)
# Out:
# Best Hyperparameters:
# {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}

# %%
finalmodel=ExtraTreesClassifier(max_depth= None, max_features= 'auto', min_samples_leaf= 1, min_samples_split=2, n_estimators= 100)

# %%
finalmodel.fit(x_train,y_train)
pred=finalmodel.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 95.57109557109557

# %%
import joblib
joblib.dump(finalmodel,"Rain.pk1")
# Out:
# ['Rain.pk1']

# %%
model=joblib.load("Rain.pk1")

# %%
s=model.predict(x_test)

# %%
a=np.array(y_test)
z=pd.DataFrame({"pred":s,"real":a})
z
# Out:
#       pred  real
# 0        1     1
# 1        1     1
# 2        0     0
# 3        1     1
# 4        0     0
# ...    ...   ...
# 2569     0     0
# 2570     1     1
# 2571     0     0
# 2572     0     1
# 2573     1     1
#
# [2574 rows x 2 columns]

# %%
# By seeing up a table we can see there are model is predicting the right values so we can say that our model is a good model and good to go

# %%
df
# Out:
#       MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0        13.4  22.900000  0.938143     1.523649  7.632205           13
# 1         7.4  25.100000  0.000000     1.523649  7.632205           14
# 2        12.9  25.700000  0.000000     1.523649  7.632205           15
# 3         9.2  28.000000  0.000000     1.523649  7.632205            4
# 4        17.5  32.300000  1.000000     1.523649  7.632205           13
# ...       ...        ...       ...          ...       ...          ...
# 8420      2.8  23.400000  0.000000     1.523649  7.632205            0
# 8421      3.6  25.300000  0.000000     1.523649  7.632205            6
# 8422      5.4  26.900000  0.000000     1.523649  7.632205            3
# 8423      7.8  27.000000  0.000000     1.523649  7.632205            9
# 8424     14.9  23.859976  0.000000     1.523649  7.632205            3
#
#       WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  ...  Humidity9am  \
# ...

# %%
x=df.drop("Rainfall",axis=1)

# %%
y=df["Rainfall"]

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#        MinTemp       MaxTemp  Evaporation      Sunshine  WindGustDir  \
# 0     0.038425 -1.570089e-01     0.204766  1.257472e-15     1.229643
# 1    -1.076989  2.028121e-01     0.204766  1.257472e-15     1.442303
# 2    -0.054526  3.009450e-01     0.204766  1.257472e-15     1.654964
# 3    -0.742365  6.771214e-01     0.204766  1.257472e-15    -0.684299
# 4     0.800625  1.380408e+00     0.204766  1.257472e-15     1.229643
# ...        ...           ...          ...           ...          ...
# 8420 -1.932140 -7.523137e-02     0.204766  1.257472e-15    -1.534940
# 8421 -1.783418  2.355231e-01     0.204766  1.257472e-15    -0.258979
# 8422 -1.448794  4.972110e-01     0.204766  1.257472e-15    -0.896959
# 8423 -1.002628  5.135665e-01     0.204766  1.257472e-15     0.379002
# 8424  0.317279 -2.905320e-15     0.204766  1.257472e-15    -0.896959
#
#       WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif values"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["feature"]=x.columns
vif
# Out:
#     vif values        feature
# 0     8.050215        MinTemp
# 1    26.283305        MaxTemp
# 2     1.412760    Evaporation
# 3     1.944572       Sunshine
# 4     1.584012    WindGustDir
# 5     2.452256  WindGustSpeed
# 6     1.334939     WindDir9am
# 7     1.477159     WindDir3pm
# 8     2.011068   WindSpeed9am
# 9     1.953380   WindSpeed3pm
# 10    3.870717    Humidity9am
# 11    5.692156    Humidity3pm
# 12   20.562965    Pressure9am
# 13   19.536281    Pressure3pm
# 14    1.934755       Cloud9am
# 15    1.834156       Cloud3pm
# 16   16.922289        Temp9am
# 17   32.856116        Temp3pm
# 18    1.392035      RainToday
# 19    1.446554   RainTomorrow

# %%
x=x.drop("Temp3pm",axis=1)
x=x.drop("Temp9am",axis=1)
x=x.drop("Pressure9am",axis=1)

# %%
# We are again dropping some fields so the data is not Multicorrelated and lead to overfitted model

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif values"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["feature"]=x.columns
vif
# Out:
#     vif values        feature
# 0     4.257961        MinTemp
# 1     5.391087        MaxTemp
# 2     1.399907    Evaporation
# 3     1.935197       Sunshine
# 4     1.565264    WindGustDir
# 5     2.382129  WindGustSpeed
# 6     1.315156     WindDir9am
# 7     1.395855     WindDir3pm
# 8     1.990678   WindSpeed9am
# 9     1.896800   WindSpeed3pm
# 10    2.358481    Humidity9am
# 11    3.103197    Humidity3pm
# 12    1.473554    Pressure3pm
# 13    1.918413       Cloud9am
# 14    1.821005       Cloud3pm
# 15    1.371842      RainToday
# 16    1.442831   RainTomorrow

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression




random_state_values = range(1, 200)

best_random_state = 0
best_accuracy = 0

for random_state in random_state_values:
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10, random_state=random_state)
    
    
    model = LinearRegression()
    model.fit(x_train, y_train)
    
    
    y_pred = model.predict(x_test)
    
    
    accuracy = r2_score(y_test, y_pred)
    
    
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_random_state = random_state

print("Best random_state:", best_random_state)
print("Best accuracy:", best_accuracy)
# Out:
# Best random_state: 144
# Best accuracy: 0.7590197700666915

# %%
 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10, random_state=144)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge
from sklearn.ensemble import GradientBoostingRegressor

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
predl=lr.predict(x_test)
pred_l=lr.predict(x_train)
print("r2score result",(r2_score(y_test,predl)))
print("r2score result on train data",r2_score(y_train,pred_l))
print("Mean square error",mean_squared_error(y_test,predl))
print("Mean absolute error",mean_absolute_error(y_test,predl))
print("root mean square error",np.sqrt(mean_squared_error(y_test,predl)))
# Out:
# r2score result 0.7590197700666915
# r2score result on train data 0.7044949910884629
# Mean square error 0.07961305448291581
# Mean absolute error 0.20568602941825706
# root mean square error 0.28215785383879677

# %%
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
predr=rf.predict(x_test)
pred_r=rf.predict(x_train)
print("r2score result",(r2_score(y_test,predr)))
print("r2score result on train data",r2_score(y_train,pred_r))
print("Mean square error",mean_squared_error(y_test,predr))
print("Mean absolute error",mean_absolute_error(y_test,predr))
print("root mean square error",np.sqrt(mean_squared_error(y_test,predr)))
# Out:
# r2score result 0.877158497092889
# r2score result on train data 0.9736012312544255
# Mean square error 0.040583359333724846
# Mean absolute error 0.13823070301025345
# root mean square error 0.20145311944401567

# %%
Dt=DecisionTreeRegressor()
Dt.fit(x_train,y_train)
predd=Dt.predict(x_test)
pred_d=Dt.predict(x_train)
print("r2score result",(r2_score(y_test,predd)))
print("r2score result on train data",r2_score(y_train,pred_d))
print("Mean square error",mean_squared_error(y_test,predd))
print("Mean absolute error",mean_absolute_error(y_test,predd))
print("root mean square error",np.sqrt(mean_squared_error(y_test,predd)))
# Out:
# r2score result 0.7442369008152537
# r2score result on train data 0.998816006724614
# Mean square error 0.08449689651200776
# Mean absolute error 0.1123735941563229
# root mean square error 0.290683498864328

# %%
from sklearn.neighbors import KNeighborsRegressor 
KNN = KNeighborsRegressor(n_neighbors=5)

KNN.fit(x_train, y_train)

predk=KNN.predict(x_test)
pred_k=KNN.predict(x_train)
print("r2score result",(r2_score(y_test,predk)))
print("r2score result on train data",r2_score(y_train,pred_k))
print("Mean square error",mean_squared_error(y_test,predk))
print("Mean absolute error",mean_absolute_error(y_test,predk))
print("root mean square error",np.sqrt(mean_squared_error(y_test,predk)))
# Out:
# r2score result 0.7529344874834434
# r2score result on train data 0.8041648191552888
# Mean square error 0.08162345979283751
# Mean absolute error 0.1804840243491448
# root mean square error 0.2856981970416291

# %%
Gb=GradientBoostingRegressor()
Gb.fit(x_train, y_train)
predg=Gb.predict(x_test)
pred_g=Gb.predict(x_train)
print("r2score result",(r2_score(y_test,predg)))
print("r2score result on train data",r2_score(y_train,pred_g))
print("Mean square error",mean_squared_error(y_test,predg))
print("Mean absolute error",mean_absolute_error(y_test,predg))
print("root mean square error",np.sqrt(mean_squared_error(y_test,predg)))
# Out:
# r2score result 0.7807168630274094
# r2score result on train data 0.7556411034521954
# Mean square error 0.07244494843338396
# Mean absolute error 0.18826563469179983
# root mean square error 0.2691559927502711

# %%
lo=Lasso()
lo.fit(x_train,y_train)
predlo=lo.predict(x_test)
pred_lo=lo.predict(x_train)
print("r2score result",(r2_score(y_test,predlo)))
print("r2score result on train data",r2_score(y_train,pred_lo))
print("Mean square error",mean_squared_error(y_test,predlo))
print("Mean absolute error",mean_absolute_error(y_test,predlo))
print("root mean square error",np.sqrt(mean_squared_error(y_test,predlo)))
# Out:
# r2score result -7.517316014116204e-08
# r2score result on train data 0.0
# Mean square error 0.3303717507851731
# Mean absolute error 0.5388193491850171
# root mean square error 0.5747797411053848

# %%
ri=Ridge()
ri.fit(x_train,y_train)
predri=ri.predict(x_test)
pred_ri=ri.predict(x_train)
print("r2score result",(r2_score(y_test,predri)))
print("r2score result on train data",r2_score(y_train,pred_ri))
print("Mean square error",mean_squared_error(y_test,predri))
print("Mean absolute error",mean_absolute_error(y_test,predri))
print("root mean square error",np.sqrt(mean_squared_error(y_test,predri)))
# Out:
# r2score result 0.7590204611712799
# r2score result on train data 0.7044949775724739
# Mean square error 0.07961282616150016
# Mean absolute error 0.2056970317691561
# root mean square error 0.282157449239782

# %%
from sklearn.model_selection import cross_val_score
s=cross_val_score(lr,x,y,cv=5,scoring='r2')
print(s)
print(s.mean())
print("difference in acc", r2_score(y_test,predl)-s.mean())
# Out:
# [0.77806478 0.63378017 0.68405669 0.61860183 0.80083699]
# 0.7030680912597458
# difference in acc 0.05595167880694574

# %%
s=cross_val_score(rf,x,y)
print(s)
print(s.mean())
print("difference in acc", (r2_score(y_test,predr)-s.mean()))
# Out:
# [0.74433806 0.75348023 0.84143482 0.6959229  0.77153629]
# 0.7613424575581569
# difference in acc 0.11581603953473207

# %%
s=cross_val_score(Dt,x,y)
print(s)
print(s.mean())
print("difference in acc", r2_score(y_test,predd)-s.mean())
# Out:
# [0.40210649 0.61411857 0.72057607 0.54800667 0.39527174]
# 0.5360159081453142
# difference in acc 0.20822099266993954

# %%
s=cross_val_score(KNN,x,y)
print(s)
print(s.mean())
print("difference in acc", r2_score(y_test,predk)-s.mean())
# Out:
# [0.69009679 0.63824223 0.69610294 0.60699518 0.70090306]
# 0.6664680399746856
# difference in acc 0.08646644750875776

# %%
s=cross_val_score(Gb,x,y)
print(s)
print(s.mean())
print("difference in acc", r2_score(y_test,predg)-s.mean())
# Out:
# [0.77455103 0.66752994 0.71146167 0.62602122 0.81168912]
# 0.7182505950326755
# difference in acc 0.06246626799473387

# %%
s=cross_val_score(lo,x,y)
print(s)
print(s.mean())
print("difference in acc", r2_score(y_test,predlo)-s.mean())
# Out:
# [-0.00116509 -0.0154399  -0.00597462 -0.01045774 -0.08889431]
# -0.024386330663863153
# difference in acc 0.024386255490703012

# %%
s=cross_val_score(ri,x,y)
print(s)
print(s.mean())
print("difference in acc", r2_score(y_test,predri)-s.mean())
# Out:
# [0.77805477 0.6337836  0.68405341 0.61861563 0.80084652]
# 0.703070785956133
# difference in acc 0.05594967521514682

# %%
# we are using GradientBoostingRegressor As it has the best R2 square and Crossval score then other models

# %%
finalmodel= GradientBoostingRegressor()
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [50, 100],
    'max_depth': [None, 10],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'max_features': ['sqrt', 'log2'],
    'subsample': [0.8, 0.9], 
    'learning_rate': [0.01, 0.1], 
}


grid_search = GridSearchCV(estimator=finalmodel, param_grid=param_grid, cv=5,)
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.01, 0.1], 'max_depth': [None, 10],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5], 'n_estimators': [50, 100],
#                          'subsample': [0.8, 0.9]})

# %%
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'learning_rate': 0.1, 'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'subsample': 0.9}

# %%
Lmodel = GradientBoostingRegressor(learning_rate= 0.1,max_depth=None, max_features='log2', min_samples_leaf=1,
                          min_samples_split=2, n_estimators=100, subsample=0.9)
Lmodel.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(max_depth=None, max_features='log2', subsample=0.9)

# %%
Gb=GradientBoostingRegressor()
Gb.fit(x_train, y_train)
predg=Gb.predict(x_test)
pred_g=Gb.predict(x_train)
print("r2score result",(r2_score(y_test,predg)))
print("r2score result on train data",r2_score(y_train,pred_g))
print("Mean square error",mean_squared_error(y_test,predg))
print("Mean absolute error",mean_absolute_error(y_test,predg))
print("root mean square error",np.sqrt(mean_squared_error(y_test,predg)))
# Out:
# r2score result 0.7805658062925586
# r2score result on train data 0.7556411034521954
# Mean square error 0.07249485330759303
# Mean absolute error 0.18841813538815036
# root mean square error 0.269248683019236

# %%
import pickle
filename="Rainfall.pk1"
pickle.dump(Lmodel,open(filename,'wb'))

# %%
smodel=pickle.load(open("Rainfall.pk1",'rb'))

# %%
re=smodel.predict(x_test)

# %%
con=pd.DataFrame([smodel.predict(x_test)[:],y_test[:]],index=["pred","og"])

# %%
con
# Out:
#            0         1         2         3         4         5         6    \
# pred  0.026221  1.288670  0.000096  0.102759  1.511164  0.000021  1.166248
# og    0.000000  1.330158  0.000000  0.000000  1.511197  0.000000  1.375312
#
#            7         8         9    ...       833       834       835  \
# pred  0.052195  0.000022  0.089105  ... -0.000473  1.598329  0.005537
# og    0.000000  0.000000  0.000000  ...  0.000000  1.598366  0.000000
#
#            836       837       838       839       840       841       842
# pred  0.146977  1.042953  0.319906  1.023062  0.202036  0.529909  0.000616
# og    0.000000  1.042956  0.817765  1.023052  0.817765  0.891780  0.000000
#
# [2 rows x 843 columns]

# %%
# My seeing above values we can see the time model is predating somewhat the right values so it is good to go
