# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("C:\\Users\\vinay\\Downloads\\loan_prediction.csv")

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# as data have null values we have first fill them

# %%
def un(df, a):
    unique_values = df[a].unique()
    return unique_values
coloumn=[]
coloumn=df.columns.tolist()
for i in coloumn:
    print(i)
    print(un(df,i))
    print("\n")
# Out:
# Loan_ID
# ['LP001002' 'LP001003' 'LP001005' 'LP001006' 'LP001008' 'LP001011'
#  'LP001013' 'LP001014' 'LP001018' 'LP001020' 'LP001024' 'LP001027'
#  'LP001028' 'LP001029' 'LP001030' 'LP001032' 'LP001034' 'LP001036'
#  'LP001038' 'LP001041' 'LP001043' 'LP001046' 'LP001047' 'LP001050'
#  'LP001052' 'LP001066' 'LP001068' 'LP001073' 'LP001086' 'LP001087'
#  'LP001091' 'LP001095' 'LP001097' 'LP001098' 'LP001100' 'LP001106'
#  'LP001109' 'LP001112' 'LP001114' 'LP001116' 'LP001119' 'LP001120'
#  'LP001123' 'LP001131' 'LP001136' 'LP001137' 'LP001138' 'LP001144'
#  'LP001146' 'LP001151' 'LP001155' 'LP001157' 'LP001164' 'LP001179'
#  'LP001186' 'LP001194' 'LP001195' 'LP001197' 'LP001198' 'LP001199'
#  'LP001205' 'LP001206' 'LP001207' 'LP001213' 'LP001222' 'LP001225'
#  'LP001228' 'LP001233' 'LP001238' 'LP001241' 'LP001243' 'LP001245'
#  'LP001248' 'LP001250' 'LP001253' 'LP001255' 'LP001256' 'LP001259'
#  'LP001263' 'LP001264' 'LP001265' 'LP001266' 'LP001267' 'LP001273'
# ...

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df=df.drop("Loan_ID",axis=1)

# %%
df["Gender"] = df["Gender"].fillna(df["Gender"].mode().iloc[0])

# %%
df["Married"] = df["Married"].fillna(df["Married"].mode().iloc[0])

# %%
df["Dependents"] = df["Dependents"].fillna(df["Dependents"].mode().iloc[0])

# %%
df["Self_Employed"] = df["Self_Employed"].fillna(df["Self_Employed"].mode().iloc[0])

# %%
df["Credit_History"] = df["Credit_History"].fillna(df["Credit_History"].mode().iloc[0])

# %%
df["LoanAmount"] = df["LoanAmount"].fillna(df["LoanAmount"].mean())

# %%
df["Loan_Amount_Term"] = df["Loan_Amount_Term"].fillna(df["Loan_Amount_Term"].mean())

# %%
# the above code are used to fill NAs with mean and mode

# %%
df.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
def un(df, a):
    unique_values = df[a].unique()
    return unique_values
coloumn=[]
coloumn=df.columns.tolist()
for i in coloumn:
    print(i)
    print(un(df,i))
    print("\n")
# Out:
# Gender
# ['Male' 'Female']
#
#
# Married
# ['No' 'Yes']
#
#
# Dependents
# ['0' '1' '2' '3+']
#
#
# Education
# ['Graduate' 'Not Graduate']
#
#
# Self_Employed
# ['No' 'Yes']
#
#
# ApplicantIncome
# [ 5849  4583  3000  2583  6000  5417  2333  3036  4006 12841  3200  2500
#   3073  1853  1299  4950  3596  3510  4887  2600  7660  5955  3365  3717
#   9560  2799  4226  1442  3750  4166  3167  4692  3500 12500  2275  1828
#   3667  3748  3600  1800  2400  3941  4695  3410  5649  5821  2645  4000
#   1928  3086  4230  4616 11500  2708  2132  3366  8080  3357  3029  2609
#   4945  5726 10750  7100  4300  3208  1875  4755  5266  1000  3333  3846
#   2395  1378  3988  2366  8566  5695  2958  6250  3273  4133  3620  6782
#   2484  1977  4188  1759  4288  4843 13650  4652  3816  3052 11417  7333
#   3800  2071  5316  2929  3572  7451  5050 14583  2214  5568 10408  5667
#   2137  2957  3692 23803  3865 10513  6080 20166  2014  2718  3459  4895
# ...

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  146.412162        342.000000
# std        6109.041673        2926.248369   84.037468         64.372489
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2877.500000           0.000000  100.250000        360.000000
# 50%        3812.500000        1188.500000  129.000000        360.000000
# 75%        5795.000000        2297.250000  164.750000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History
# count      614.000000
# mean         0.855049
# std          0.352339
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()

# %%
# we need to encode the data so model can understand it better

# %%
df.dtypes
# Out:
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df["Gender"].dtypes
# Out:
# dtype('O')

# %%
for col1 in df.columns:
    if df[col1].dtypes=="O":
        dfp=lab.fit_transform(df[col1])
        df[col1]=dfp

# %%
# with help of this code we are able to encode data which have string value in it

# %%
df.dtypes
# Out:
# Gender                 int32
# Married                int32
# Dependents             int32
# Education              int32
# Self_Employed          int32
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area          int32
# Loan_Status            int32
# dtype: object

# %%
df.describe()
# Out:
#            Gender     Married  Dependents   Education  Self_Employed  \
# count  614.000000  614.000000  614.000000  614.000000     614.000000
# mean     0.817590    0.653094    0.744300    0.218241       0.133550
# std      0.386497    0.476373    1.009623    0.413389       0.340446
# min      0.000000    0.000000    0.000000    0.000000       0.000000
# 25%      1.000000    0.000000    0.000000    0.000000       0.000000
# 50%      1.000000    1.000000    0.000000    0.000000       0.000000
# 75%      1.000000    1.000000    1.000000    0.000000       0.000000
# max      1.000000    1.000000    3.000000    1.000000       1.000000
#
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  146.412162        342.000000
# std        6109.041673        2926.248369   84.037468         64.372489
# ...

# %%
def un(df, a):
    unique_values = df[a].unique()
    return unique_values
coloumn=[]
coloumn=df.columns.tolist()
for i in coloumn:
    print(i)
    print(un(df,i))
    print("\n")
# Out:
# Gender
# [1 0]
#
#
# Married
# [0 1]
#
#
# Dependents
# [0 1 2 3]
#
#
# Education
# [0 1]
#
#
# Self_Employed
# [0 1]
#
#
# ApplicantIncome
# [ 5849  4583  3000  2583  6000  5417  2333  3036  4006 12841  3200  2500
#   3073  1853  1299  4950  3596  3510  4887  2600  7660  5955  3365  3717
#   9560  2799  4226  1442  3750  4166  3167  4692  3500 12500  2275  1828
#   3667  3748  3600  1800  2400  3941  4695  3410  5649  5821  2645  4000
#   1928  3086  4230  4616 11500  2708  2132  3366  8080  3357  3029  2609
#   4945  5726 10750  7100  4300  3208  1875  4755  5266  1000  3333  3846
#   2395  1378  3988  2366  8566  5695  2958  6250  3273  4133  3620  6782
#   2484  1977  4188  1759  4288  4843 13650  4652  3816  3052 11417  7333
#   3800  2071  5316  2929  3572  7451  5050 14583  2214  5568 10408  5667
#   2137  2957  3692 23803  3865 10513  6080 20166  2014  2718  3459  4895
#   3316 14999  4200  5042  6950  2698 11757  2330 14866  1538 10000  4860
# ...

# %%
df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0             5849
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          1              0             2583
# 4         1        0           0          0              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0             2900
# 610       1        1           3          0              0             4106
# 611       1        1           1          0              0             8072
# 612       1        1           2          0              0             7583
# 613       0        0           0          0              1             4583
#
# ...

# %%
plt.figure(figsize=(24,24),facecolor="yellow")
plnum=1

for i in df.columns:
    if plnum<=23:
        ax=plt.subplot(5,5,plnum)
        sns.distplot(df[i])
        plt.xlabel(i,fontsize=20)
        
    plnum+=1
plt.show()

# %%
plt.figure(figsize=(24,24),facecolor="yellow")
plnum=1

for i in df:
    if plnum<=23:
        ax=plt.subplot(5,5,plnum)
        sns.boxplot(data=df[i])
        plt.xlabel(i,fontsize=20)
        
    plnum+=1
plt.show()

# %%
plt.figure(figsize=(24, 24), facecolor="yellow")
plnum = 1

for i in df:
    if plnum <= 20:
        ax = plt.subplot(4, 5, plnum)
        plt.scatter(df[i], df["Loan_Status"]) 
        plt.xlabel(i, fontsize=20)
        plt.ylabel("Loan_Status", fontsize=20)
    plnum += 1

plt.tight_layout()

# %%
df.skew()
# Out:
# Gender              -1.648795
# Married             -0.644850
# Dependents           1.015551
# Education            1.367622
# Self_Employed        2.159796
# ApplicantIncome      6.539513
# CoapplicantIncome    7.491531
# LoanAmount           2.726601
# Loan_Amount_Term    -2.389680
# Credit_History      -2.021971
# Property_Area       -0.066196
# Loan_Status         -0.809998
# dtype: float64

# %%
# the data have Skewness which have to be reduced

# %%
def skwe(a,df):
    df[a]=np.sqrt(df[a])

# %%
skwe("ApplicantIncome",df)
skwe("CoapplicantIncome",df)
skwe("LoanAmount",df)
skwe("Loan_Amount_Term",df)
skwe("Credit_History",df)

# %%
df.skew()
# Out:
# Gender              -1.648795
# Married             -0.644850
# Dependents           1.015551
# Education            1.367622
# Self_Employed        2.159796
# ApplicantIncome      0.640611
# CoapplicantIncome   -0.220321
# LoanAmount          -0.114662
# Loan_Amount_Term    -4.530463
# Credit_History      -2.021971
# Property_Area       -0.066196
# Loan_Status         -0.809998
# dtype: float64

# %%
cor=df.corr()
cor
# Out:
#                      Gender   Married  Dependents  Education  Self_Employed  \
# Gender             1.000000  0.364569    0.172914   0.045364      -0.000525
# Married            0.364569  1.000000    0.334216   0.012304       0.004489
# Dependents         0.172914  0.334216    1.000000   0.055752       0.056798
# Education          0.045364  0.012304    0.055752   1.000000      -0.010383
# Self_Employed     -0.000525  0.004489    0.056798  -0.010383       1.000000
# ApplicantIncome    0.083640  0.022760    0.116848  -0.182435       0.190710
# CoapplicantIncome  0.222294  0.329316    0.005287   0.056044      -0.099469
# LoanAmount         0.143782  0.179944    0.157352  -0.145187       0.110319
# Loan_Amount_Term  -0.055779 -0.071349   -0.079878  -0.066668      -0.026917
# Credit_History     0.009170  0.010938   -0.040160  -0.073658      -0.001550
# Property_Area     -0.025752  0.004257   -0.000244  -0.065243      -0.030860
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),linewidths=0.2,fmt=".2g",linecolor="black",annot=True,cmap="Blues_r")
plt.yticks(rotation=0);
plt.show()

# %%
cor['Loan_Status'].sort_values(ascending=False)
# Out:
# Loan_Status          1.000000
# Credit_History       0.540556
# Married              0.091478
# CoapplicantIncome    0.071728
# Property_Area        0.032112
# Gender               0.017987
# ApplicantIncome      0.010233
# Dependents           0.010118
# Self_Employed       -0.003700
# Loan_Amount_Term    -0.008031
# LoanAmount          -0.042103
# Education           -0.085884
# Name: Loan_Status, dtype: float64

# %%
x=df.drop('Loan_Status',axis=1)

# %%
y=df['Loan_Status']

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#        Gender   Married  Dependents  Education  Self_Employed  \
# 0    0.472343 -1.372089   -0.737806  -0.528362      -0.392601
# 1    0.472343  0.728816    0.253470  -0.528362      -0.392601
# 2    0.472343  0.728816   -0.737806  -0.528362       2.547117
# 3    0.472343  0.728816   -0.737806   1.892641      -0.392601
# 4    0.472343 -1.372089   -0.737806  -0.528362      -0.392601
# ..        ...       ...         ...        ...            ...
# 609 -2.117107 -1.372089   -0.737806  -0.528362      -0.392601
# 610  0.472343  0.728816    2.236021  -0.528362      -0.392601
# 611  0.472343  0.728816    0.253470  -0.528362      -0.392601
# 612  0.472343  0.728816    1.244745  -0.528362      -0.392601
# 613 -2.117107 -1.372089   -0.737806  -0.528362       2.547117
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           0.505980          -1.117049    0.243713          0.272829
# 1           0.127257           0.868509   -0.028005          0.272829
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif values"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["feature"]=x.columns
vif
# Out:
#     vif values            feature
# 0     1.203471             Gender
# 1     1.405781            Married
# 2     1.175046         Dependents
# 3     1.066974          Education
# 4     1.043212      Self_Employed
# 5     1.857723    ApplicantIncome
# 6     1.549781  CoapplicantIncome
# 7     1.590867         LoanAmount
# 8     1.036853   Loan_Amount_Term
# 9     1.009527     Credit_History
# 10    1.025569      Property_Area

# %%
y.value_counts()
# Out:
# 1    422
# 0    192
# Name: Loan_Status, dtype: int64

# %%
# the data is not balance so we need to create a balane data so model have better to data to Learn on

# %%
from imblearn.over_sampling import SMOTE

# %%
sm=SMOTE()
x,y=sm.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 1    422
# 0    422
# Name: Loan_Status, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score


random_state_values = range(1, 300)

best_random_state = 0
best_accuracy = 0

for random_state in random_state_values:
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=random_state)
    
    
    model = RandomForestClassifier()
    model.fit(x_train, y_train)
    
    
    y_pred = model.predict(x_test)
    
    
    accuracy = accuracy_score(y_test, y_pred)
    
    
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_random_state = random_state

print("Best random_state:", best_random_state)
print("Best accuracy:", best_accuracy)
# Out:
# Best random_state: 131
# Best accuracy: 0.893491124260355

# %%
#the best accuracy is at 131

# %%
 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=131)

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,accuracy_score
from sklearn.model_selection import cross_val_score

# %%
def model(x):
    x.fit(x_train,y_train)
    pred=x.predict(x_test)
    print(accuracy_score(y_test,pred))
    print(confusion_matrix(y_test,pred))
    print(classification_report(y_test,pred))

# %%
ref=RandomForestClassifier()
model(ref)
# Out:
# 0.8994082840236687
# [[65 11]
#  [ 6 87]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.88        76
#            1       0.89      0.94      0.91        93
#
#     accuracy                           0.90       169
#    macro avg       0.90      0.90      0.90       169
# weighted avg       0.90      0.90      0.90       169

# %%
ln=LogisticRegression()
model(ln)
# Out:
# 0.6804733727810651
# [[35 41]
#  [13 80]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.46      0.56        76
#            1       0.66      0.86      0.75        93
#
#     accuracy                           0.68       169
#    macro avg       0.70      0.66      0.66       169
# weighted avg       0.69      0.68      0.67       169

# %%
ex=ExtraTreesClassifier()
model(ex)
# Out:
# 0.8579881656804734
# [[62 14]
#  [10 83]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84        76
#            1       0.86      0.89      0.87        93
#
#     accuracy                           0.86       169
#    macro avg       0.86      0.85      0.86       169
# weighted avg       0.86      0.86      0.86       169

# %%
svc=SVC()
model(svc)
# Out:
# 0.7692307692307693
# [[48 28]
#  [11 82]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.63      0.71        76
#            1       0.75      0.88      0.81        93
#
#     accuracy                           0.77       169
#    macro avg       0.78      0.76      0.76       169
# weighted avg       0.78      0.77      0.76       169

# %%
ad=AdaBoostClassifier()
model(ad)
# Out:
# 0.7692307692307693
# [[53 23]
#  [16 77]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.70      0.73        76
#            1       0.77      0.83      0.80        93
#
#     accuracy                           0.77       169
#    macro avg       0.77      0.76      0.76       169
# weighted avg       0.77      0.77      0.77       169

# %%
bg=BaggingClassifier()
model(bg)
# Out:
# 0.8402366863905325
# [[65 11]
#  [16 77]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83        76
#            1       0.88      0.83      0.85        93
#
#     accuracy                           0.84       169
#    macro avg       0.84      0.84      0.84       169
# weighted avg       0.84      0.84      0.84       169

# %%
def crossval(a):
    s=cross_val_score(a,x,y)
    pr=a.predict(x_test)
    print(s)
    print(s.mean())
    print("difference in acc", accuracy_score(y_test,pr)-s.mean())

# %%
crossval(ln)
# Out:
# [0.68639053 0.72189349 0.65680473 0.68047337 0.69642857]
# 0.6883981403212174
# difference in acc -0.007924767540152255

# %%
crossval(ref)
# Out:
# [0.75739645 0.75147929 0.86390533 0.88757396 0.91071429]
# 0.834213863060017
# difference in acc 0.06519442096365169

# %%
crossval(ex)
# Out:
# [0.76923077 0.78698225 0.89349112 0.90532544 0.875     ]
# 0.8460059171597634
# difference in acc 0.01198224852071006

# %%
crossval(svc)
# Out:
# [0.71597633 0.74556213 0.70414201 0.76923077 0.74404762]
# 0.7357917723302339
# difference in acc 0.03343899690053542

# %%
crossval(ad)
# Out:
# [0.72189349 0.71005917 0.78106509 0.79881657 0.76190476]
# 0.7547478162862779
# difference in acc 0.014482952944491423

# %%
crossval(bg)
# Out:
# [0.73964497 0.73372781 0.82248521 0.81656805 0.86904762]
# 0.7962947309101156
# difference in acc 0.043941955480416905

# %%
# see the Result of cross validation and confusing matrix the best model is ExtraTreesClassifier

# %%
from sklearn.model_selection import GridSearchCV
param_grid =  {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2'],
}

# %%
GGV=GridSearchCV(ExtraTreesClassifier(),param_grid,cv=5)

# %%
GGV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesClassifier(),
#              param_grid={'max_depth': [None, 10, 20],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]})

# %%
best_params = GGV.best_params_

print("Best Hyperparameters:")
print(best_params)
# Out:
# Best Hyperparameters:
# {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}

# %%
finalmodel=ExtraTreesClassifier(max_depth= 20, max_features= 'sqrt', min_samples_leaf= 1, min_samples_split=2, n_estimators= 200)

# %%
finalmodel.fit(x_train,y_train)
pred=finalmodel.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 87.57396449704143

# %%
import joblib
joblib.dump(finalmodel,"Loan.pk1")
# Out:
# ['Loan.pk1']

# %%
model=joblib.load("Loan.pk1")

# %%
s=model.predict(x_test)

# %%
a=np.array(y_test)
z=pd.DataFrame({"pred":s,"real":a})
z
# Out:
#      pred  real
# 0       0     0
# 1       0     0
# 2       1     0
# 3       0     0
# 4       1     1
# ..    ...   ...
# 164     1     1
# 165     0     0
# 166     0     0
# 167     1     0
# 168     1     1
#
# [169 rows x 2 columns]
