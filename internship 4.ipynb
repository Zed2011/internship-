# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd 
import selenium
from selenium.webdriver.common.by import By  
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time
import re
from selenium.common.exceptions import NoSuchElementException

# %%
driver=webdriver.Chrome()
driver.get("https://www.amazon.in")

# %%
product_name = input("Enter the product name to search for: ")
des=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
des.send_keys(product_name)
# Out:
# Enter the product name to search for: guitar

# %%
ser=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
ser.click()

# %%
urls=[]
for page in range(0,1):
    url=driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    
    for i in url:
        urls.append(i.get_attribute("href"))
    
    next_button = driver.find_element(By.XPATH, "/html/body/div[1]/div[2]/div[1]/div[1]/div/span[1]/div[1]/div[63]/div/div/span/a[3]")
    next_button.click()

urls
# Out:
# ['https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo2OTk5MzE0MTU3NDczNjA2OjE2OTMzOTI4NzQ6c3BfYXRmOjMwMDAxNTUzNzk3OTIzMjo6MDo6&url=%2FKadence-Frontier-Acoustic-Guitar-Strings%2Fdp%2FB078GTJP5Y%2Fref%3Dsr_1_1_sspa%3Fcrid%3D217MRUZLND8JH%26keywords%3Dguitar%26qid%3D1693392874%26sprefix%3Dguitar%252Caps%252C377%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1',
#  'https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo2OTk5MzE0MTU3NDczNjA2OjE2OTMzOTI4NzQ6c3BfYXRmOjMwMDAyNTIxNzI0MTYzMjo6MDo6&url=%2FMedellin-Acoustic-Guitar-learning-Strings%2Fdp%2FB0CCNSN6S4%2Fref%3Dsr_1_2_sspa%3Fcrid%3D217MRUZLND8JH%26keywords%3Dguitar%26qid%3D1693392874%26sprefix%3Dguitar%252Caps%252C377%26sr%3D8-2-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1',
# ...

# %%
len(urls)
# Out:
# 59

# %%
from selenium.common.exceptions import NoSuchElementException
import time


driver = webdriver.Chrome()

name = []
price = []
delivery = []
avi = []

for i in urls:
    driver.get(i)
    time.sleep(5) 
    
    try:
        a = driver.find_element(By.XPATH, "/html/body/div[2]/div[2]/div[5]/div[3]/div[4]/div[1]/div/h1/span")
        name.append(a.text)
    except NoSuchElementException:
        name.append("-")
    
    try:
        b = driver.find_element(By.CLASS_NAME, "a-price-whole")
        price.append(b.text)
    except NoSuchElementException:
        price.append('-')
    
    try:
        c = driver.find_element(By.XPATH, "/html/body/div[2]/div[2]/div[5]/div[3]/div[4]/div[23]/div[2]/div/div/div/div[2]/div/ol/li[1]/div/div[2]/span")
        delivery.append(c.text)
    except NoSuchElementException:
        delivery.append('-')
    
    try:
        d = driver.find_element(By.XPATH, "/html/body/div[2]/div[2]/div[5]/div[3]/div[1]/div[3]/div/div[1]/div/div/div/form/div/div/div/div/div[3]/div/div[4]/div/div[1]/span")
        avi.append(d.text)
    except NoSuchElementException:
        avi.append('-')

# %%
complete=pd.DataFrame({'name':name,'price': price,'delivery':delivery,'In_stock':avi,'url':urls})
complete
# Out:
#                                                  name   price       delivery  \
# 0   Kadence rosewood Guitar Frontier Series, Elect...   4,999  Free Delivery
# 1   Medellin Acoustic Guitar (with guitar learning...   2,499  Free Delivery
# 2   Kadence Slowhand Premium Jumbo Semi Acoustic G...  11,999  Free Delivery
# 3   Vault DA20 Dreadnought Acoustic Guitar With Gi...   4,899  Free Delivery
# 4   Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...   1,999  Free Delivery
# 5   Intern INT-38C Right hand Acoustic Guitar Kit,...   1,999  Free Delivery
# 6   Intern INT-38C Lindenwood Acoustic Guitar Kit ...   2,149  Free Delivery
# 7   Yamaha F280 Acoustic Rosewood Guitar (Natural,...   7,399  Free Delivery
# 8                                                   -   1,999              -
# 9                                                   -   1,999              -
# 10  Intern 38C Acoustic Steel-string Guitar Premiu...   2,149  Free Delivery
# ...

# %%
keywords = ['fruits', 'cars', 'Machine Learning', 'Guitar', 'Cakes']
res = []

for keyword in keywords:
    driver = webdriver.Chrome()
    driver.get("https://images.google.com/")

    search_input = driver.find_element(By.NAME, "q")
    search_input.send_keys(keyword)
    time.sleep(5)
    search_button = driver.find_element(By.XPATH, "/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div")
    search_button.click()
    driver.execute_script("window.scrollBy(0, 1000)")
    images = driver.find_elements(By.XPATH, "//img[@class='rg_i Q4LuWd']")

    img_urls = []
    for img in images:
        src = img.get_attribute('src')
        if src and src.startswith('http'):
            img_urls.append(src)

    for i in range(min(10, len(img_urls))):
        img_url = img_urls[i]
        response = requests.get(img_url)
        if response.status_code == 200:
            
            with open(f"D:/sahil/data internship/image_{i}.jpg", "wb") as file:
                file.write(response.content)
        else:
            print(f"Failed to download image {i}")

# %%
driver=webdriver.Chrome()
driver.get("https://www.flipkart.com/")
product_name = input("Enter the product name to search for: ")
des=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")
des.send_keys(product_name)
but=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
but.click()
# Out:
# Enter the product name to search for: onepule phone

# %%
urls=[]
url=driver.find_elements(By.XPATH,"//a[@class='_1fQZEK']")
 
for i in url:
    urls.append(i.get_attribute("href"))

# %%
from selenium.common.exceptions import NoSuchElementException
import time



name = []
price = []
ram = []
rom = []
fca = []
bca = []
battery = []
display = []
url = []


for i in urls:
    driver.get(i)
    time.sleep(5) 
    try:
        d = driver.find_element(By.XPATH, "/html/body/div[1]/div/div[3]/div[1]/div[2]/div[2]/div/div[1]/h1/span")
        name.append(d.text)
    except NoSuchElementException:
        avi.append('-')
        
    try:
        d = driver.find_element(By.XPATH, "/html/body/div[1]/div/div[3]/div[1]/div[2]/div[2]/div/div[3]/div[1]/div/div")
        price.append(d.text)
    except NoSuchElementException:
        price.append('-')
        
    try:
        d = driver.find_element(By.XPATH, "/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div[1]/div/div[2]/ul/li[1]")
        ram.append(d.text)
    except NoSuchElementException:
        ram.append('-')
        
    try:
        d = driver.find_element(By.XPATH, "/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div[1]/div/div[2]/ul/li[2]")
        display.append(d.text)
    except NoSuchElementException:
        display.append('-')
        
    try:
        d = driver.find_element(By.XPATH, "/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div[1]/div/div[2]/ul/li[3]")
        fca.append(d.text)
    except NoSuchElementException:
        fca.append('-')
    try:
        d = driver.find_element(By.XPATH, "/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div[1]/div/div[2]/ul/li[4]")
        battery.append(d.text)
    except NoSuchElementException:
        battery.append('-')

# %%
complete=pd.DataFrame({"Name":name,"Price": price,"Ram|Rom":ram,"Display":display,"Frontcamer/backcamer":fca,"Battery":battery,"urls":urls})

# %%
csv_file_path = "D:\sahil\oneplus.csv"

complete.to_csv(csv_file_path, index=False)

print(f"DataFrame saved to {csv_file_path}")
# Out:
# DataFrame saved to D:\sahil\oneplus.csv

# %%
driver=webdriver.Chrome()
driver.get("https://www.google.com/maps")
name = input("Enter the place name to search for: ")
des=driver.find_element(By.XPATH,"/html/body/div[3]/div[8]/div[3]/div[1]/div[1]/div/div[2]/form/input")
des.send_keys(name)
but=driver.find_element(By.XPATH,"/html/body/div[3]/div[8]/div[3]/div[1]/div[1]/div/div[2]/div[1]")
but.click()
try:
    url = driver.current_url 
    lat_lag = re.findall(r'@([0-9.-]+),([0-9.-]+)', url) 
    if lat_lag:
        latitude, longitude = lat_lag[0]  
        print("Latitude:", latitude)
        print("Longitude:", longitude)
    else:
        print("Coordinates not found in the URL.")
        
except Exception as e:
    print(f"An error occurred: {str(e)}")
# Out:
# Enter the place name to search for: delhi
# Latitude: 28.6162944
# Longitude: 77.3718016

# %%
driver=webdriver.Chrome()
driver.get("https://www.digit.in/top-products/best-gaming-laptops-40.html")

# %%
namel=[]
os=[]
price=[]
gp=[]
sc=[]
m=[]
name=driver.find_elements(By.XPATH,"//span[@class='datahreflink']")
for i in name[0:7]:
    namel.append(i.text)
name=driver.find_elements(By.XPATH,"//div[@class='Specs-Wrap']/ul/li[1]")
for i in name[0:7]:
    os.append(i.text)    
    name=driver.find_elements(By.XPATH,"//div[@class='Specs-Wrap']/ul/li[2]")
for i in name[0:7]:
    sc.append(i.text) 
name=driver.find_elements(By.XPATH,"//div[@class='Specs-Wrap']/ul/li[4]")
for i in name[0:7]:
    gp.append(i.text)
name=driver.find_elements(By.XPATH,"//div[@class='Spcs-details']/table/tbody/tr[8]/td[3]")
for i in name[0:7]:
    price.append(i.text)
name=driver.find_elements(By.XPATH,"//div[@class='Specs-Wrap']/ul/li[5]")
for i in name[0:7]:
    m.append(i.text)
complete=pd.DataFrame({"Name":namel,"OS":os,"Price":price,"Processor":gp,"display":sc,"Mermory":m})
complete
# Out:
#                           Name               OS      Price  \
# 0            HP OMEN 17 (2023)  Windows 11 Home  ₹ 269,777
# 1         MSI Titan GT77 12UHS  Windows 11 Home  ₹ 499,990
# 2         Lenovo Legion 5i Pro  Windows 11 Home  ₹ 179,990
# 3  ASUS ROG Strix Scar 18 2023  Windows 11 Home  ₹ 279,990
# 4  Acer Predator Helios Neo 16  Windows 11 Home  ₹ 149,990
# 5        ASUS ROG Zephyrus G14  Windows 11 Home  ₹ 156,990
# 6                MSI Cyborg 15  Windows 11 Home  ₹ 125,000
#
#                                   Processor              display  \
# 0  13th Gen Intel Core i7-13700HX | 5.0 GHz  17.3" (2560 x 1440)
# 1  12th Gen Intel Core i9-12900HX | 3.6 GHz  17.3" (3840 x 2160)
# 2   12th Gen Intel Core i7-12700H | 4.7 GHz    16" (2560 x 1600)
# 3  13th Gen Intel Core i9-13980HX | 2.2 GHz    18" (1920 x 1200)
# 4       13th Gen Intel Core i7-13700HX | NA    16" (2560 x 1600)
# 5              AMD Ryzen 9-6900HS | 4.9 GHz    14" (1920 x 1200)
# ...

# %%
comments=[]
votes=[]
day=[]
driver=webdriver.Chrome()
driver.get("https://www.youtube.com/watch?v=YfUFGP9c0P4")
time.sleep(20)
for _ in range(0,20):
    driver.execute_script("window.scrollBy(0, 10000000)")
    time.sleep(20)
    driver.execute_script("window.scrollBy(0, 1000000000)")
try:
    com=driver.find_elements(By.XPATH,'//span[@id="vote-count-middle"]')
    for i in com[0:500]:
        votes.append(i.text if i.text else '_')
except NoSuchElementException:
        votes.append('-')
            
try:
    com=driver.find_elements(By.XPATH,'//yt-formatted-string[@id="content-text"]')
    for i in com[0:500]:
        comments.append(i.text if i.text else '_')
except NoSuchElementException:
        comments.append('-')
    
try:
    com=driver.find_elements(By.XPATH,'//a[@class="yt-simple-endpoint style-scope yt-formatted-string"]')
    for i in com[0:500]:
        day.append(i.text if i.text else '_')
except NoSuchElementException:
        day.append('-')

# %%
youtube=pd.DataFrame({"comments":comments[1:400],"votes":votes[1:400],"time":day[1:400]})
youtube
# Out:
#                                               comments votes        time
# 0    This phone surviving the durability test was i...    1K           _
# 1    Jerry not only did not break the flexible scre...   952  4 days ago
# 2    Absolutely! It's mind-blowing to see how flip ...   119  4 days ago
# 3    zack swapping from a standard phone to a folda...   776  4 days ago
# 4    That may have been the absolute best teardown ...    21  4 days ago
# ..                                                 ...   ...         ...
# 394  2:20 For a brief moment, it gave me a rollable...     _  4 days ago
# 395                Z flip 5 is really truly the "TOOL"     _  3 days ago
# 396  Are all of the razor knifes plastic handled?\n...     _  4 days ago
# 397  Could you poke debrand please, to see if they ...     _  4 days ago
# 398  Ooohh Would be interesting to come back in 4 y...     _        2:30
#
# [399 rows x 3 columns]

# %%
driver=webdriver.Chrome()
driver.get("https://www.hostelworld.com/pwa/wds/s?q=London,%20England&country=London&city=London&type=city&id=3&from=2023-09-10&to=2023-09-13&guests=2&page=1")

# %%
u = []
des = driver.find_elements(By.XPATH, '//a[@class="property-card-container horizontal"]')
for i in des:
    u.append(i.get_attribute("href"))

# %%
name = []
price = []
rev= []
rat = []
distance = []
p_d = []
dp = []
pp= []


for i in u:
    driver.get(i)
    time.sleep(5) 
    try:
        d = driver.find_element(By.XPATH, "/html/body/div[3]/div/div/div[2]/section/div[4]/div/div[1]/h1/div")
        name.append(d.text)
    except NoSuchElementException:
        name.append('-')
    try:
        d = driver.find_element(By.XPATH, "/html/body/div[3]/div/div/div[2]/section/div[12]/div[1]/div/div[1]")
        rat.append(d.text)
    except NoSuchElementException:
        rat.append('-')
    try:
        d = driver.find_element(By.XPATH, "/html/body/div[3]/div/div/div[2]/section/div[12]/div[1]/div/div[2]/div[2]")
        rev.append(d.text)
    except NoSuchElementException:
        rev.append('-')
    try:
        d = driver.find_element(By.XPATH, "/html/body/div[3]/div/div/div[2]/section/div[11]/div/div/section/div/div[1]/div/div[1]/div[2]/div/div[2]/div[1]/div/div[1]/div[2]/div[1]")
        p_d.append(d.text)
    except NoSuchElementException:
        p_d.append('-')
        
    try:
        d = driver.find_element(By.XPATH, "/html/body/div[3]/div/div/div[2]/section/div[11]/div/div/section/div/div[1]/div/div[2]/div[2]/div[1]/div[2]/div[1]/div/div[1]/div[2]/div[1]")
        dp.append(d.text)
    except NoSuchElementException:
        dp.append('-') 
    try:
        d = driver.find_element(By.XPATH, "/html/body/div[3]/div/div/div[2]/section/div[9]/div/div[2]/div[4]/div/div[2]")
        pp.append(d.text)
    except NoSuchElementException:
        pp.append('-')

# %%
df= pd.DataFrame({"Name":name,"ratings":rat, "total reviews":rev, "privates from price":p_d, "dorms from price":dp,"property description":pp})
