# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("C:\\Users\\vinay\\Downloads\\termdeposit_train.csv")
df
# Out:
#           ID  age         job   marital  education default  balance housing  \
# 0      26110   56      admin.   married    unknown      no     1933      no
# 1      40576   31     unknown   married  secondary      no        3      no
# 2      15320   27    services   married  secondary      no      891     yes
# 3      43962   57  management  divorced   tertiary      no     3287      no
# 4      29842   31  technician   married  secondary      no      119     yes
# ...      ...  ...         ...       ...        ...     ...      ...     ...
# 31642  36483   29  management    single   tertiary      no        0     yes
# 31643  40178   53  management  divorced   tertiary      no      380      no
# 31644  19710   32  management    single   tertiary      no      312      no
# 31645  38556   57  technician   married  secondary      no      225     yes
# 31646  14156   55  management  divorced  secondary      no      204     yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31647 entries, 0 to 31646
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          31647 non-null  int64
#  1   age         31647 non-null  int64
#  2   job         31647 non-null  object
#  3   marital     31647 non-null  object
#  4   education   31647 non-null  object
#  5   default     31647 non-null  object
#  6   balance     31647 non-null  int64
#  7   housing     31647 non-null  object
#  8   loan        31647 non-null  object
#  9   contact     31647 non-null  object
#  10  day         31647 non-null  int64
#  11  month       31647 non-null  object
#  12  duration    31647 non-null  int64
#  13  campaign    31647 non-null  int64
#  14  pdays       31647 non-null  int64
#  15  previous    31647 non-null  int64
#  16  poutcome    31647 non-null  object
#  17  subscribed  31647 non-null  object
# dtypes: int64(8), object(10)
# memory usage: 4.3+ MB

# %%
df.isnull().sum()
# Out:
# ID            0
# age           0
# job           0
# marital       0
# education     0
# default       0
# balance       0
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# subscribed    0
# dtype: int64

# %%
df.dtypes
# Out:
# ID             int64
# age            int64
# job           object
# marital       object
# education     object
# default       object
# balance        int64
# housing       object
# loan          object
# contact       object
# day            int64
# month         object
# duration       int64
# campaign       int64
# pdays          int64
# previous       int64
# poutcome      object
# subscribed    object
# dtype: object

# %%
def un(df, a):
    unique_values = df[a].unique()
    return unique_values
coloumn=[]
coloumn=df.columns.tolist()
for i in coloumn:
    print(i)
    print(un(df,i))
    print("\n")
# Out:
# ID
# [26110 40576 15320 ... 19710 38556 14156]
#
#
# age
# [56 31 27 57 33 50 45 35 36 44 39 43 41 53 64 48 60 29 30 42 46 32 63 47
#  49 52 68 26 58 38 54 40 59 24 37 34 61 55 20 69 25 62 22 51 28 70 66 23
#  87 71 74 81 73 76 72 84 19 79 75 21 83 80 67 18 77 65 82 86 78 88 92 95
#  93 89 94 90]
#
#
# job
# ['admin.' 'unknown' 'services' 'management' 'technician' 'retired'
#  'blue-collar' 'housemaid' 'self-employed' 'student' 'entrepreneur'
#  'unemployed']
#
#
# marital
# ['married' 'divorced' 'single']
#
#
# education
# ['unknown' 'secondary' 'tertiary' 'primary']
#
#
# default
# ['no' 'yes']
#
#
# balance
# [1933    3  891 ... 2787 8741 2968]
#
#
# housing
# ['no' 'yes']
#
#
# loan
# ['no' 'yes']
#
#
# contact
# ['telephone' 'cellular' 'unknown']
#
#
# day
# [19 20 18 22  4  2  3  8 15  5 28  6 14  7 24 13  9 11 21 12 30 27 17 16
#  25 10  1 29 26 31 23]
#
#
# month
# ['nov' 'jul' 'jun' 'feb' 'sep' 'jan' 'may' 'aug' 'apr' 'oct' 'mar' 'dec']
#
#
# duration
# ...

# %%
df=df.drop("ID",axis=1)

# %%
df["pdays"].mean()
# Out:
# 39.576041962903275

# %%
df.loc[df['pdays'] == -1, 'pdays'] = df['pdays'].mean()

# %%
df['pdays'] = df['pdays'].astype('int64')

# %%
def un(df, a):
    unique_values = df[a].unique()
    return unique_values
coloumn=[]
coloumn=df.columns.tolist()
for i in coloumn:
    print(i)
    print(un(df,i))
    print("\n")
# Out:
# age
# [56 31 27 57 33 50 45 35 36 44 39 43 41 53 64 48 60 29 30 42 46 32 63 47
#  49 52 68 26 58 38 54 40 59 24 37 34 61 55 20 69 25 62 22 51 28 70 66 23
#  87 71 74 81 73 76 72 84 19 79 75 21 83 80 67 18 77 65 82 86 78 88 92 95
#  93 89 94 90]
#
#
# job
# ['admin.' 'unknown' 'services' 'management' 'technician' 'retired'
#  'blue-collar' 'housemaid' 'self-employed' 'student' 'entrepreneur'
#  'unemployed']
#
#
# marital
# ['married' 'divorced' 'single']
#
#
# education
# ['unknown' 'secondary' 'tertiary' 'primary']
#
#
# default
# ['no' 'yes']
#
#
# balance
# [1933    3  891 ... 2787 8741 2968]
#
#
# housing
# ['no' 'yes']
#
#
# loan
# ['no' 'yes']
#
#
# contact
# ['telephone' 'cellular' 'unknown']
#
#
# day
# [19 20 18 22  4  2  3  8 15  5 28  6 14  7 24 13  9 11 21 12 30 27 17 16
#  25 10  1 29 26 31 23]
#
#
# month
# ['nov' 'jul' 'jun' 'feb' 'sep' 'jan' 'may' 'aug' 'apr' 'oct' 'mar' 'dec']
#
#
# duration
# [  44   91  240 ...  939  839 1973]
#
#
# campaign
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()

# %%
dfp=lab.fit_transform(df["job"])
pd.Series(dfp)
# Out:
# 0         0
# 1        11
# 2         7
# 3         4
# 4         9
#          ..
# 31642     4
# 31643     4
# 31644     4
# 31645     9
# 31646     4
# Length: 31647, dtype: int32

# %%
df["job"]=dfp

# %%
dfm=lab.fit_transform(df["marital"])
pd.Series(dfm)
df["marital"]=dfm

# %%
dfe=lab.fit_transform(df["education"])
pd.Series(dfe)
df["education"]=dfe

# %%
dfd=lab.fit_transform(df["default"])
pd.Series(dfd)
df["default"]=dfd

# %%
dfh=lab.fit_transform(df["housing"])
pd.Series(dfh)
df["housing"]=dfh

# %%
dfl=lab.fit_transform(df["loan"])
pd.Series(dfl)
df["loan"]=dfl

# %%
dfc=lab.fit_transform(df["contact"])
pd.Series(dfc)
df["contact"]=dfc

# %%
dfo=lab.fit_transform(df["month"])
pd.Series(dfo)
df["month"]=dfo

# %%
dfp=lab.fit_transform(df["poutcome"])
pd.Series(dfp)
df["poutcome"]=dfp

# %%
dfs=lab.fit_transform(df["subscribed"])
pd.Series(dfs)
df["subscribed"]=dfs

# %%
df
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       56    0        1          3        0     1933        0     0        1
# 1       31   11        1          1        0        3        0     0        0
# 2       27    7        1          1        0      891        1     0        0
# 3       57    4        0          2        0     3287        0     0        0
# 4       31    9        1          1        0      119        1     0        0
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 31642   29    4        2          2        0        0        1     0        0
# 31643   53    4        0          2        0      380        0     1        0
# 31644   32    4        2          2        0      312        0     0        0
# 31645   57    9        1          1        0      225        1     0        1
# 31646   55    4        0          1        0      204        1     0        0
#
# ...

# %%
df.nunique().to_frame("no.of unique values")
# Out:
#             no.of unique values
# age                          76
# job                          12
# marital                       3
# education                     4
# default                       2
# balance                    6326
# housing                       2
# loan                          2
# contact                       3
# day                          31
# month                        12
# duration                   1454
# campaign                     45
# pdays                       508
# previous                     38
# poutcome                      4
# subscribed                    2

# %%
df.describe()
# Out:
#                 age           job       marital     education       default  \
# count  31647.000000  31647.000000  31647.000000  31647.000000  31647.000000
# mean      40.957247      4.332923      1.167220      1.225013      0.018485
# std       10.625134      3.271868      0.607186      0.749195      0.134700
# min       18.000000      0.000000      0.000000      0.000000      0.000000
# 25%       33.000000      1.000000      1.000000      1.000000      0.000000
# 50%       39.000000      4.000000      1.000000      1.000000      0.000000
# 75%       48.000000      7.000000      2.000000      2.000000      0.000000
# max       95.000000     11.000000      2.000000      3.000000      1.000000
#
#              balance       housing          loan       contact           day  \
# count   31647.000000  31647.000000  31647.000000  31647.000000  31647.000000
# mean     1363.890258      0.555629      0.162132      0.644642     15.835466
# ...

# %%
plt.figure(figsize=(24,24),facecolor="yellow")
plnum=1

for i in coloumn:
    if plnum<=18:
        ax=plt.subplot(5,5,plnum)
        sns.distplot(df[i])
        plt.xlabel(i,fontsize=20)
        
    plnum+=1
plt.show()

# %%
plt.figure(figsize=(24,24),facecolor="yellow")
plnum=1

for i in df:
    if plnum<=18:
        ax=plt.subplot(5,4,plnum)
        sns.boxplot(data=df[i])
        plt.xlabel(i,fontsize=20)
        
    plnum+=1
plt.show()

# %%
plt.figure(figsize=(24, 24), facecolor="yellow")
plnum = 1

for i in df:
    if plnum <= 18:
        ax = plt.subplot(5, 4, plnum)
        plt.scatter(df[i], df["subscribed"]) 
        plt.xlabel(i, fontsize=20)
        plt.ylabel("subscribed", fontsize=20)
    plnum += 1

plt.tight_layout()

# %%
df.skew()
# Out:
# age            0.681607
# job            0.264817
# marital       -0.100071
# education      0.199441
# default        7.149903
# balance        7.995696
# housing       -0.223918
# loan           1.833474
# contact        0.758602
# day            0.087185
# month         -0.486498
# duration       3.199766
# campaign       4.873935
# pdays          2.923166
# previous      49.302348
# poutcome      -1.996421
# subscribed     2.377445
# dtype: float64

# %%
def skwe(a,df):
    df[a]=np.sqrt(df[a])

# %%
skwe("duration",df)

# %%
df.skew()
# Out:
# age           0.681607
# job           0.264817
# marital      -0.100071
# education     0.199441
# default       7.149903
# balance       0.040650
# housing      -0.223918
# loan          1.833474
# contact       0.758602
# day           0.087185
# month        -0.486498
# duration      0.379350
# campaign      1.136596
# poutcome     -1.996421
# subscribed    2.377445
# dtype: float64

# %%
df.isnull().sum()
# Out:
# age              0
# job              0
# marital          0
# education        0
# default          0
# balance       2665
# housing          0
# loan             0
# contact          0
# day              0
# month            0
# duration         0
# campaign         0
# poutcome         0
# subscribed       0
# dtype: int64

# %%
df["balance"].fillna(df["balance"].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# age           0
# job           0
# marital       0
# education     0
# default       0
# balance       0
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# poutcome      0
# subscribed    0
# dtype: int64

# %%
df=df.drop("previous",axis=1)
df=df.drop("pdays",axis=1)

# %%
#droping previous and pdays because of high skewness
# Out:
# (array([    0,     1,     2, ..., 31644, 31645, 31646], dtype=int64),)

# %%
cor=df.corr()
cor
# Out:
#                  age       job   marital  education   default   balance  \
# age         1.000000 -0.020765 -0.406024  -0.102356 -0.016117  0.089723
# job        -0.020765  1.000000  0.066124   0.170347 -0.005217  0.011743
# marital    -0.406024  0.066124  1.000000   0.107547 -0.009591  0.018117
# education  -0.102356  0.170347  0.107547   1.000000 -0.006774  0.051271
# default    -0.016117 -0.005217 -0.009591  -0.006774  1.000000 -0.073446
# balance     0.089723  0.011743  0.018117   0.051271 -0.073446  1.000000
# housing    -0.183775 -0.125347 -0.017846  -0.095376 -0.011823 -0.014718
# loan       -0.012657 -0.039049 -0.041654  -0.045950  0.081567 -0.068934
# contact     0.026733 -0.078253 -0.040180  -0.112000  0.014053 -0.010772
# day        -0.011056  0.020951 -0.007686   0.017902  0.009996  0.001963
# month      -0.038368 -0.089384 -0.003834  -0.055967  0.004694  0.034943
# duration   -0.008473  0.001790  0.013530   0.002849 -0.009646  0.043715
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),linewidths=0.2,fmt=".2g",linecolor="black",annot=True,cmap="Blues_r")
plt.yticks(rotation=0);
plt.show()

# %%
cor['subscribed'].sort_values(ascending=False)
# Out:
# subscribed    1.000000
# duration      0.371917
# balance       0.076491
# education     0.066051
# marital       0.046043
# job           0.038921
# age           0.024538
# default      -0.020168
# month        -0.028088
# day          -0.029600
# loan         -0.072266
# poutcome     -0.080895
# campaign     -0.083219
# housing      -0.141092
# contact      -0.150051
# Name: subscribed, dtype: float64

# %%
x=df.drop('subscribed',axis=1)

# %%
y=df['subscribed']

# %%
y.value_counts()
# Out:
# 0    27932
# 1     3715
# Name: subscribed, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#             age       job   marital  education   default   balance   housing  \
# 0      1.415793 -1.324317 -0.275405   2.369229 -0.137234  0.766620 -1.118201
# 1     -0.937156  2.037729 -0.275405  -0.300345 -0.137234 -1.501829 -1.118201
# 2     -1.313627  0.815167 -0.275405  -0.300345 -0.137234  0.268422  0.894294
# 3      1.509911 -0.101755 -1.922374   1.034442 -0.137234  1.168328 -1.118201
# 4     -0.937156  1.426448 -0.275405  -0.300345 -0.137234 -0.653814  0.894294
# ...         ...       ...       ...        ...       ...       ...       ...
# 31642 -1.125392 -0.101755  1.371563   1.034442 -0.137234 -2.063573  0.894294
# 31643  1.133439 -0.101755 -1.922374   1.034442 -0.137234 -0.179039 -1.118201
# 31644 -0.843038 -0.101755  1.371563   1.034442 -0.137234 -0.269679 -1.118201
# 31645  1.509911  1.426448 -0.275405  -0.300345 -0.137234 -0.410455  0.894294
# 31646  1.321675 -0.101755 -1.922374  -0.300345 -0.137234 -0.450457  0.894294
#
# ...

# %%
# Out:
# age              0
# job              0
# marital          0
# education        0
# default          0
# balance       2665
# housing          0
# loan             0
# contact          0
# day              0
# month            0
# duration         0
# campaign         0
# poutcome         0
# subscribed       0
# dtype: int64

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif values"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["feature"]=x.columns
vif
# Out:
#     vif values    feature
# 0     1.283048        age
# 1     1.049973        job
# 2     1.224259    marital
# 3     1.065051  education
# 4     1.013164    default
# 5     1.030596    balance
# 6     1.182621    housing
# 7     1.017712       loan
# 8     1.318848    contact
# 9     1.037455        day
# 10    1.256602      month
# 11    1.025973   duration
# 12    1.080169   campaign
# 13    1.143032   poutcome

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score


random_state_values = range(1, 300)

best_random_state = 0
best_accuracy = 0

for random_state in random_state_values:
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=random_state)
    
    
    model = RandomForestClassifier()
    model.fit(x_train, y_train)
    
    
    y_pred = model.predict(x_test)
    
    
    accuracy = accuracy_score(y_test, y_pred)
    
    
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_random_state = random_state

print("Best random_state:", best_random_state)
print("Best accuracy:", best_accuracy)
# Out:
# Best random_state: 223
# Best accuracy: 0.9142180094786729

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=223)

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,accuracy_score
from sklearn.model_selection import cross_val_score

# %%
def model(x):
    x.fit(x_train,y_train)
    pred=x.predict(x_test)
    print(accuracy_score(y_test,pred))
    print(confusion_matrix(y_test,pred))
    print(classification_report(y_test,pred))

# %%
ref=RandomForestClassifier()
model(ref)
# Out:
# 0.9132701421800948
# [[5514  148]
#  [ 401  267]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      5662
#            1       0.64      0.40      0.49       668
#
#     accuracy                           0.91      6330
#    macro avg       0.79      0.69      0.72      6330
# weighted avg       0.90      0.91      0.90      6330

# %%
ln=LogisticRegression()
model(ln)
# Out:
# 0.8946287519747236
# [[5518  144]
#  [ 523  145]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94      5662
#            1       0.50      0.22      0.30       668
#
#     accuracy                           0.89      6330
#    macro avg       0.71      0.60      0.62      6330
# weighted avg       0.87      0.89      0.88      6330

# %%
ex=ExtraTreesClassifier()
model(ex)
# Out:
# 0.9102685624012639
# [[5561  101]
#  [ 467  201]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      5662
#            1       0.67      0.30      0.41       668
#
#     accuracy                           0.91      6330
#    macro avg       0.79      0.64      0.68      6330
# weighted avg       0.90      0.91      0.89      6330

# %%
svc=SVC()
model(svc)
# Out:
# 0.9074249605055292
# [[5582   80]
#  [ 506  162]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95      5662
#            1       0.67      0.24      0.36       668
#
#     accuracy                           0.91      6330
#    macro avg       0.79      0.61      0.65      6330
# weighted avg       0.89      0.91      0.89      6330

# %%
gb=GradientBoostingClassifier()
model(gb)
# Out:
# 0.9109004739336493
# [[5499  163]
#  [ 401  267]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      5662
#            1       0.62      0.40      0.49       668
#
#     accuracy                           0.91      6330
#    macro avg       0.78      0.69      0.72      6330
# weighted avg       0.90      0.91      0.90      6330

# %%
ad=AdaBoostClassifier()
model(ad)
# Out:
# 0.9018957345971564
# [[5488  174]
#  [ 447  221]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95      5662
#            1       0.56      0.33      0.42       668
#
#     accuracy                           0.90      6330
#    macro avg       0.74      0.65      0.68      6330
# weighted avg       0.89      0.90      0.89      6330

# %%
bg=BaggingClassifier()
model(bg)
# Out:
# 0.9053712480252765
# [[5478  184]
#  [ 415  253]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      5662
#            1       0.58      0.38      0.46       668
#
#     accuracy                           0.91      6330
#    macro avg       0.75      0.67      0.70      6330
# weighted avg       0.89      0.91      0.90      6330

# %%
def crossval(a):
    s=cross_val_score(a,x,y)
    pr=a.predict(x_test)
    print(s)
    print(s.mean())
    print("difference in acc", accuracy_score(y_test,pr)-s.mean())

# %%
crossval(ln)
# Out:
# [0.89036335 0.89020537 0.88655396 0.88686996 0.88686996]
# 0.8881725211338164
# difference in acc 0.0064562308409071845

# %%
crossval(ref)
# Out:
# [0.90315956 0.90647709 0.90045821 0.9055143  0.90282825]
# 0.903687481856506
# difference in acc 0.009582660323588787

# %%
crossval(ex)
# Out:
# [0.90063191 0.89968404 0.90188023 0.89951019 0.89935219]
# 0.9002117138266467
# difference in acc 0.010056848574617194

# %%
crossval(svc)
# Out:
# [0.89605055 0.89778831 0.89508611 0.89492811 0.89398009]
# 0.8955666348913713
# difference in acc 0.011858325614157894

# %%
crossval(gb)
# Out:
# [0.90679305 0.90489731 0.90030021 0.90346026 0.9001422 ]
# 0.903118606719439
# difference in acc 0.0077818672142102585

# %%
crossval(ad)
# Out:
# [0.89652449 0.8985782  0.89334808 0.89492811 0.89666614]
# 0.8960090029171868
# difference in acc 0.00588673167996967

# %%
crossval(bg)
# Out:
# [0.89510269 0.8957346  0.89603413 0.89666614 0.89492811]
# 0.8956931320182404
# difference in acc 0.009678116007036053

# %%
# by looking at all the result and crossval we can say that RandomForestClassifier() is best model as it cross val score is good 
# also its have a good accuary 
# so we go with RandomForestClassifier() as model for this data

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2'],
    'class_weight': [None, 'balanced']
}

# %%
GCV= GridSearchCV(RandomForestClassifier(), param_grid, cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'class_weight': [None, 'balanced'],
#                          'max_depth': [None, 10, 20],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 150]})

# %%
best_params = GCV.best_params_

print("Best Hyperparameters:")
print(best_params)
# Out:
# Best Hyperparameters:
# {'class_weight': None, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 150}

# %%
final_model=RandomForestClassifier(class_weight= None, max_depth= 20, max_features= 'sqrt', min_samples_leaf= 2, min_samples_split= 5, n_estimators= 150)
final_model.fit(x_train,y_train)
pred=final_model.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 91.50078988941547

# %%
import joblib
joblib.dump(final_model,"Bank.pk1")
# Out:
# ['Bank.pk1']

# %%
model=joblib.load("Bank.pk1")

# %%
s=model.predict(x_test)

# %%
a=np.array(y_test)
z=pd.DataFrame({"pred":s,"real":a})
z
# Out:
# <bound method NDFrame.head of       pred  real
# 0        0     1
# 1        0     1
# 2        0     0
# 3        0     1
# 4        0     0
# ...    ...   ...
# 6325     0     0
# 6326     0     1
# 6327     0     0
# 6328     0     0
# 6329     0     0
#
# [6330 rows x 2 columns]>
