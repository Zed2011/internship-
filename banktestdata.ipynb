# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df2=pd.read_csv("C:\\Users\\vinay\\Downloads\\termdeposit_test.csv")
df2
# Out:
#           ID  age            job   marital  education default  balance  \
# 0      38441   32       services   married  secondary      no      118
# 1      40403   78        retired  divorced    primary      no     2787
# 2       3709   31  self-employed    single   tertiary      no      144
# 3      37422   57       services    single    primary      no     3777
# 4      12527   45    blue-collar  divorced  secondary      no     -705
# ...      ...  ...            ...       ...        ...     ...      ...
# 13559  23465   39     management   married   tertiary      no       45
# 13560  11743   54    blue-collar   married    primary      no     2281
# 13561  28292   35        retired   married    primary      no      285
# 13562  45163   29         admin.    single  secondary      no      464
# 13563  34839   29         admin.   married  secondary      no        2
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
df2.isnull().sum()
# Out:
# ID           0
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %%
df2=df2.drop("ID",axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()
dfp=lab.fit_transform(df2["job"])
pd.Series(dfp)
df2["job"]=dfp

# %%
dfm=lab.fit_transform(df2["marital"])
pd.Series(dfm)
df2["marital"]=dfm
dfe=lab.fit_transform(df2["education"])
pd.Series(dfe)
df2["education"]=dfe
dfd=lab.fit_transform(df2["default"])
pd.Series(dfd)
df2["default"]=dfd
dfh=lab.fit_transform(df2["housing"])
pd.Series(dfh)
df2["housing"]=dfh
dfl=lab.fit_transform(df2["loan"])
pd.Series(dfl)
df2["loan"]=dfl
dfc=lab.fit_transform(df2["contact"])
pd.Series(dfc)
df2["contact"]=dfc
dfo=lab.fit_transform(df2["month"])
pd.Series(dfo)
df2["month"]=dfo
dfp=lab.fit_transform(df2["poutcome"])
pd.Series(dfp)
df2["poutcome"]=dfp

# %%
df2
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       32    7        1          1        0      118        1     0        0
# 1       78    5        0          0        0     2787        0     0        1
# 2       31    6        2          2        0      144        1     0        2
# 3       57    7        2          0        0     3777        1     0        1
# 4       45    1        0          1        0     -705        0     1        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 13559   39    4        1          2        0       45        0     0        0
# 13560   54    1        1          0        0     2281        1     0        2
# 13561   35    5        1          0        0      285        1     0        0
# 13562   29    0        2          1        0      464        0     0        0
# 13563   29    0        1          1        0        2        1     0        0
#
# ...

# %%
df2=df2.drop("previous",axis=1)
df2=df2.drop("pdays",axis=1)

# %%
x2=df2

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x2=pd.DataFrame(scaler.fit_transform(x2),columns=x2.columns)
x2
# Out:
#             age       job   marital  education   default   balance   housing  \
# 0     -0.838114  0.807551 -0.276592  -0.301053 -0.131336 -0.402389  0.893033
# 1      3.499987  0.196760 -1.914173  -1.642982 -0.131336  0.463375 -1.119779
# 2     -0.932421  0.502156  1.360988   1.040875 -0.131336 -0.393955  0.893033
# 3      1.519549  0.807551  1.360988  -1.642982 -0.131336  0.784508  0.893033
# 4      0.387871 -1.024823 -1.914173  -0.301053 -0.131336 -0.669352 -1.119779
# ...         ...       ...       ...        ...       ...       ...       ...
# 13559 -0.177969 -0.108636 -0.276592   1.040875 -0.131336 -0.426069 -1.119779
# 13560  1.236630 -1.024823 -0.276592  -1.642982 -0.131336  0.299239  0.893033
# 13561 -0.555195  0.196760 -0.276592  -1.642982 -0.131336 -0.348218  0.893033
# 13562 -1.121034 -1.330219  1.360988  -0.301053 -0.131336 -0.290155 -1.119779
# 13563 -1.121034 -1.330219 -0.276592  -0.301053 -0.131336 -0.440017  0.893033
#
# ...

# %%
import joblib
model=joblib.load("Bank.pk1")

# %%
s=model.predict(x2)

# %%
df2['subscribed'] = s

# %%
df2
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       32    7        1          1        0      118        1     0        0
# 1       78    5        0          0        0     2787        0     0        1
# 2       31    6        2          2        0      144        1     0        2
# 3       57    7        2          0        0     3777        1     0        1
# 4       45    1        0          1        0     -705        0     1        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 13559   39    4        1          2        0       45        0     0        0
# 13560   54    1        1          0        0     2281        1     0        2
# 13561   35    5        1          0        0      285        1     0        0
# 13562   29    0        2          1        0      464        0     0        0
# 13563   29    0        1          1        0        2        1     0        0
#
# ...
