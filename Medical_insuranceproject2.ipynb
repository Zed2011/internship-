# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df=pd.read_csv('C:\\Users\\vinay\\Downloads\\medical_cost_insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# the data type is perfect all have been define acc. to the data

# %%
def un(df, a):
    unique_values = df[a].unique()
    return unique_values
coloumn=[]
coloumn=df.columns.tolist()
for i in coloumn:
    print(i)
    print(un(df,i))
    print("\n")
# Out:
# age
# [19 18 28 33 32 31 46 37 60 25 62 23 56 27 52 30 34 59 63 55 22 26 35 24
#  41 38 36 21 48 40 58 53 43 64 20 61 44 57 29 45 54 49 47 51 42 50 39]
#
#
# sex
# ['female' 'male']
#
#
# bmi
# [27.9   33.77  33.    22.705 28.88  25.74  33.44  27.74  29.83  25.84
#  26.22  26.29  34.4   39.82  42.13  24.6   30.78  23.845 40.3   35.3
#  36.005 32.4   34.1   31.92  28.025 27.72  23.085 32.775 17.385 36.3
#  35.6   26.315 28.6   28.31  36.4   20.425 32.965 20.8   36.67  39.9
#  26.6   36.63  21.78  30.8   37.05  37.3   38.665 34.77  24.53  35.2
#  35.625 33.63  28.    34.43  28.69  36.955 31.825 31.68  22.88  37.335
#  27.36  33.66  24.7   25.935 22.42  28.9   39.1   36.19  23.98  24.75
#  28.5   28.1   32.01  27.4   34.01  29.59  35.53  39.805 26.885 38.285
#  37.62  41.23  34.8   22.895 31.16  27.2   26.98  39.49  24.795 31.3
#  38.28  19.95  19.3   31.6   25.46  30.115 29.92  27.5   28.4   30.875
#  27.94  35.09  29.7   35.72  32.205 28.595 49.06  27.17  23.37  37.1
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()

# %%
dfs=lab.fit_transform(df["sex"])
pd.Series(dfs)
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1333    1
# 1334    0
# 1335    0
# 1336    0
# 1337    0
# Length: 1338, dtype: int32

# %%
dfso=lab.fit_transform(df["smoker"])
pd.Series(dfso)
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1333    0
# 1334    0
# 1335    0
# 1336    0
# 1337    1
# Length: 1338, dtype: int32

# %%
dfr=lab.fit_transform(df["region"])
pd.Series(dfr)
# Out:
# 0       3
# 1       2
# 2       2
# 3       1
# 4       1
#        ..
# 1333    1
# 1334    0
# 1335    2
# 1336    3
# 1337    1
# Length: 1338, dtype: int32

# %%
df["sex"]=dfs

# %%
df["region"]=dfr
df["smoker"]=dfso

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %%
# we encoded the data for sex smoker and region

# %%
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64
#
#
# 1    676
# 0    662
# Name: sex, dtype: int64
#
#
# 32.300    13
# 28.310     9
# 30.495     8
# 30.875     8
# 31.350     8
#           ..
# 46.200     1
# 23.800     1
# 44.770     1
# 32.120     1
# 30.970     1
# Name: bmi, Length: 548, dtype: int64
#
#
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64
#
#
# 0    1064
# 1     274
# Name: smoker, dtype: int64
#
#
# 2    364
# 3    325
# 1    325
# ...

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.dtypes
# Out:
# age           int64
# sex           int32
# bmi         float64
# children      int64
# smoker        int32
# region        int32
# charges     float64
# dtype: object

# %%
# all data type is perfect acc. to the data

# %%
df.nunique().to_frame("no.of unique values")
# Out:
#           no.of unique values
# age                        47
# sex                         2
# bmi                       548
# children                    6
# smoker                      2
# region                      4
# charges                  1337

# %%
plt.figure(figsize=(24,24),facecolor="yellow")
plnum=1

for i in coloumn:
    if plnum<=12:
        ax=plt.subplot(4,4,plnum)
        sns.distplot(df[i])
        plt.xlabel(i,fontsize=20)
        
    plnum+=1
plt.show()

# %%
# somewhat the data is off

# %%
plt.figure(figsize=(24,24),facecolor="yellow")
plnum=1

for i in df:
    if plnum<=12:
        ax=plt.subplot(4,3,plnum)
        sns.boxplot(data=df[i])
        plt.xlabel(i,fontsize=20)
        
    plnum+=1
plt.show()

# %%
plt.figure(figsize=(24, 24), facecolor="yellow")
plnum = 1

for i in df:
    if plnum <= 12:
        ax = plt.subplot(4, 3, plnum)
        plt.scatter(df[i], df["charges"]) 
        plt.xlabel(i, fontsize=20)
        plt.ylabel("charger", fontsize=20)
    plnum += 1

plt.tight_layout()

# %%
sns.pairplot(data=df,palette="dark")

# %%
df.skew()
# Out:
# age         0.055673
# sex        -0.020951
# bmi         0.284047
# children    0.938380
# smoker      1.464766
# region     -0.038101
# charges     1.515880
# dtype: float64

# %%
cor=df.corr()
cor
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000 -0.020856  0.109272  0.042469 -0.025019  0.002127  0.299008
# sex      -0.020856  1.000000  0.046371  0.017163  0.076185  0.004588  0.057292
# bmi       0.109272  0.046371  1.000000  0.012759  0.003750  0.157566  0.198341
# children  0.042469  0.017163  0.012759  1.000000  0.007673  0.016569  0.067998
# smoker   -0.025019  0.076185  0.003750  0.007673  1.000000 -0.002181  0.787251
# region    0.002127  0.004588  0.157566  0.016569 -0.002181  1.000000 -0.006208
# charges   0.299008  0.057292  0.198341  0.067998  0.787251 -0.006208  1.000000

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),linewidths=0.2,fmt=".2g",linecolor="black",annot=True,cmap="Blues_r")
plt.yticks(rotation=0);
plt.show()

# %%
cor['charges'].sort_values(ascending=False)
# Out:
# charges     1.000000
# smoker      0.787251
# age         0.299008
# bmi         0.198341
# children    0.067998
# sex         0.057292
# region     -0.006208
# Name: charges, dtype: float64

# %%
x=df.drop('charges',axis=1)

# %%
y=df['charges']

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#            age       sex       bmi  children    smoker    region
# 0    -1.438764 -1.010519 -0.453320 -0.908614  1.970587  1.343905
# 1    -1.509965  0.989591  0.509621 -0.078767 -0.507463  0.438495
# 2    -0.797954  0.989591  0.383307  1.580926 -0.507463  0.438495
# 3    -0.441948  0.989591 -1.305531 -0.908614 -0.507463 -0.466915
# 4    -0.513149  0.989591 -0.292556 -0.908614 -0.507463 -0.466915
# ...        ...       ...       ...       ...       ...       ...
# 1333  0.768473  0.989591  0.050297  1.580926 -0.507463 -0.466915
# 1334 -1.509965 -1.010519  0.206139 -0.908614 -0.507463 -1.372326
# 1335 -1.509965 -1.010519  1.014878 -0.908614 -0.507463  0.438495
# 1336 -1.296362 -1.010519 -0.797813 -0.908614 -0.507463  1.343905
# 1337  1.551686 -1.010519 -0.261388 -0.908614  1.970587 -0.466915
#
# [1338 rows x 6 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif values"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["feature"]=x.columns
vif
# Out:
#    vif values   feature
# 0    1.015394       age
# 1    1.008889       sex
# 2    1.040608       bmi
# 3    1.002482  children
# 4    1.006466    smoker
# 5    1.025966    region

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression




random_state_values = range(1, 300)

best_random_state = 0
best_accuracy = 0

for random_state in random_state_values:
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=random_state)
    
    
    model = LinearRegression()
    model.fit(x_train, y_train)
    
    
    y_pred = model.predict(x_test)
    
    
    accuracy = r2_score(y_test, y_pred)
    
    
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_random_state = random_state

print("Best random_state:", best_random_state)
print("Best accuracy:", best_accuracy)
# Out:
# Best random_state: 215
# Best accuracy: 0.8178420745999806

# %%
# the best accuracy is ay random state at 215

# %%
  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=215)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge
from sklearn.ensemble import GradientBoostingRegressor

# %%
lr=LinearRegression()
def modelB(z):
    z.fit(x_train,y_train)
    pred=z.predict(x_test)
    pred_t=z.predict(x_train)
    print("r2score result",(r2_score(y_test,pred)))
    print("r2score result on train data",r2_score(y_train,pred_t))
    print("Mean square error",mean_squared_error(y_test,pred))
    print("Mean absolute error",mean_absolute_error(y_test,pred))
    print("root mean square error",np.sqrt(mean_squared_error(y_test,pred)))

# %%
modelB(lr)
# Out:
# r2score result 0.8178420745999806
# r2score result on train data 0.7306278759856394
# Mean square error 30060453.999165364
# Mean absolute error 4097.418614043558
# root mean square error 5482.741467474585

# %%
rf=RandomForestRegressor()
modelB(rf)
# Out:
# r2score result 0.8874528577983222
# r2score result on train data 0.9734587772141376
# Mean square error 18572994.743223503
# Mean absolute error 2476.022347628161
# root mean square error 4309.63974633884

# %%
Dt=DecisionTreeRegressor()
modelB(Dt)
# Out:
# r2score result 0.7547007775602664
# r2score result on train data 0.9987921577327152
# Mean square error 40480291.90049098
# Mean absolute error 3095.0629142350745
# root mean square error 6362.412427726686

# %%
from sklearn.neighbors import KNeighborsRegressor 
KNN = KNeighborsRegressor(n_neighbors=5)

KNN.fit(x_train, y_train)

pred=KNN.predict(x_test)
pred_t=KNN.predict(x_train)
print("r2score result",(r2_score(y_test,pred)))
print("r2score result on train data",r2_score(y_train,pred_t))
print("Mean square error",mean_squared_error(y_test,pred))
print("Mean absolute error",mean_absolute_error(y_test,pred))
print("root mean square error",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2score result 0.8808513209160684
# r2score result on train data 0.859524201038258
# Mean square error 19662407.654229134
# Mean absolute error 2802.87395096194
# root mean square error 4434.231348749086

# %%
Gb=()
modelB(Gb)
# Out:
# r2score result 0.9030135914125295
# r2score result on train data 0.8927264164346569
# Mean square error 16005098.144840892
# Mean absolute error 2266.789892877364
# root mean square error 4000.637217349368

# %%
lo=Lasso()
modelB(lo)
# Out:
# r2score result 0.8178372871140842
# r2score result on train data 0.7306278310310751
# Mean square error 30061244.04988232
# Mean absolute error 4097.5790493856575
# root mean square error 5482.813515876891

# %%
ri=Ridge()
modelB(ri)
# Out:
# r2score result 0.817773030935438
# r2score result on train data 0.7306271833899325
# Mean square error 30071847.870155934
# Mean absolute error 4099.457941446934
# root mean square error 5483.780435990844

# %%
from sklearn.model_selection import cross_val_score
def crossval(a):
    s=cross_val_score(a,x,y)
    pr=a.predict(x_test)
    print(s)
    print(s.mean())
    print("difference in acc", r2_score(y_test,pr)-s.mean()*100)

# %%
crossval(lr)
# Out:
# [0.76123983 0.70838663 0.77786772 0.73365206 0.7551335 ]
# 0.7472559473580954
# difference in acc -73.90775266120956

# %%
crossval(rf)
# Out:
# [0.8554461  0.77065658 0.86496645 0.83279512 0.85713335]
# 0.8361995206316066
# difference in acc -82.73249920536234

# %%
crossval(Dt)
# Out:
# [0.7416016  0.64458637 0.75187218 0.70647599 0.69205829]
# 0.7073188838248712
# difference in acc -69.97718760492685

# %%
crossval(KNN)
# Out:
# [0.8221881  0.7555254  0.83987794 0.8050002  0.80856984]
# 0.8062322958732286
# difference in acc -79.7423782664068

# %%
crossval(Gb)
# Out:
# [0.87510892 0.79147951 0.89420007 0.84919102 0.85967904]
# 0.8539317127841674
# difference in acc -84.4901576870042

# %%
crossval(lo)
# Out:
# [0.76124697 0.70842054 0.77784891 0.73364937 0.75513888]
# 0.7472609349374297
# difference in acc -73.90825620662889

# %%
crossval(ri)
# Out:
# [0.76124956 0.70849269 0.77774855 0.73370746 0.75510598]
# 0.7472608501582405
# difference in acc -73.90831198488861

# %%
# with the informations we can see that GradientBoostingRegressor is best model and have the best accuary

# %%
finalmodel= GradientBoostingRegressor()
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2'],
    'subsample': [0.8, 0.9, 1.0], 
    'learning_rate': [0.01, 0.1, 0.1], 
}


grid_search = GridSearchCV(estimator=finalmodel, param_grid=param_grid, cv=5,)
grid_search.fit(x,y)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.01, 0.1, 0.1],
#                          'max_depth': [None, 10, 20],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 150],
#                          'subsample': [0.8, 0.9, 1.0]})

# %%
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'learning_rate': 0.1, 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50, 'subsample': 0.8}

# %%
Lmodel = GradientBoostingRegressor(max_depth=10, max_features='log2', min_samples_leaf=4,
                          min_samples_split=10, n_estimators=50, subsample=0.8)
Lmodel.fit(x, y)
# Out:
# GradientBoostingRegressor(max_depth=10, max_features='log2', min_samples_leaf=4,
#                           min_samples_split=10, n_estimators=50, subsample=0.8)

# %%
modelB(Lmodel)
# Out:
# r2score result 0.8910555016614996
# r2score result on train data 0.9583122933844958
# Mean square error 17978471.557440624
# Mean absolute error 2536.938016152249
# root mean square error 4240.102776754429

# %%
import pickle
filename="Medical_insurance.pk1"
pickle.dump(Lmodel,open(filename,'wb'))

# %%
smodel=pickle.load(open("Medical_insurance.pk1",'rb'))

# %%
re=smodel.predict(x_test)

# %%
con=pd.DataFrame([smodel.predict(x_test)[:],y_test[:]],index=[]"pred","og"})
